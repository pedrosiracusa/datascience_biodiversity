# %%
import numpy as np
import pandas as pd
import networkx as nx

import matplotlib.pyplot as plt

import modules.names_cleaning as nc

# %matplotlib inline

# %%
dsetPath = '/home/pedro/datasets/ub_herbarium/occurrence.txt'

cols = [ 'recordedBy','scientificName','taxonRank', 'collectionCode']
occs = pd.read_csv(dsetPath, sep='\t', usecols=cols)
occs=occs[occs['recordedBy'].notnull()]

# %%
occs.head()
# Out:
#   collectionCode           recordedBy                 scientificName taxonRank
# 0             UB            Irwin, HS         Annona monticola Mart.   SPECIES
# 1             UB   Ratter, JA; et al.  Myracrodruon urundeuva Allem.   SPECIES
# 2             UB         Heringer, EP  Myracrodruon urundeuva Allem.   SPECIES
# 3             UB           Coelho, JP  Myracrodruon urundeuva Allem.   SPECIES
# 4             UB  Eiten, G; Eiten, LT  Myracrodruon urundeuva Allem.   SPECIES

# %% [markdown]
# ## Atomizing names

# %%
atomizingFunction = lambda x: nc.namesFromString(x,delim=';') 
atomized_recordedBy = nc.atomizeNames(occs['recordedBy'],operation=atomizingFunction)
occs['recordedBy_atomized'] = atomized_recordedBy

# %%
from collections import Counter

def getNamesList( col, with_counts=False, orderBy=None ):
    """
    Gets a list of names from an atomized names column.
    
    ordered: default = None
        alphabetic
        counts
    
    with_counts
    """
    
    if orderBy not in [ None, "alphabetic", "counts"]:
        raise ValueError("Invalid argument for 'orderBy': {}".format(orderBy))
    
    if with_counts or orderBy=="counts":
        l = [ (n,c) for (n,c) in Counter( n for nlst in col for n in nlst ).items() ] 
        if orderBy=="alphabetic":
            return sorted( l, key=lambda x: x[0] )
        elif orderBy=="counts":
            sorted_l = sorted( l, key=lambda x: x[1], reverse=True )
            if with_counts:
                return sorted_l
            else:
                return [ n for (n,c) in sorted_l ]
        else:
            return l
                
    else:
        if orderBy=="alphabetic":
            return sorted(list(set( n for nlst in col for n in nlst )))
        else:
            return list(set( n for nlst in col for n in nlst ))

# %%
def getRecordsBy(df, colName, name):
    return df.loc[df[colName].apply( lambda x: name in x )]

# %%
def atomizeNames( col, operation=None, replaces=None ):
    """
    Applies an atomization operation on a names column, which must be a pandas Series object. 
    The atomized names at each row are stored as a list.
    
    Parameters
    ----------
    col : pd.Series
        Names column to be atomized.
        
    operation : function
        The atomization operation to be applied to the names column
        
    replaces:
        A list of 2-tuples (srclst, tgt), where srclst is a list of names to be replaced by tgt.
        The element tgt can be either a string or a function which results in a string.
        
    Returns
    -------
        A pandas Series with lists of atomized names.
    """
    replacesDict = dict( (src, tgt(src)) if callable(tgt) else (src,tgt) for (srclst, tgt) in replaces for src in srclst )
    col = col.replace( replacesDict )
    col_atomized = col.apply( operation )
    return col_atomized

# %%
rep = [ 
    (['Sr. Air, Sr. Milton, Rodrigo'], "Sr. Air; Sr. Milton; Rodrigo"),
    (['Sônia / Josefina'], "Sônia; Josefina"),
    (['Hatschbach, G; M.'], "Hatschbach, G; Hatschbach, M"),
    (['Hällström; E.'], "Hällström, E"),
    (['Irwin, HS; Souza, R; Santos; RR'], "Irwin, HS; Souza, R; Santos, RR"),
    (['Kirkbride Junior, JH; Ono; E.K.M; et al.'], "Kirkbride Junior, JH; Ono, E.K.M; et al."),

    
    (['Carboni, M; Faraco, AG; Soares; P.G.; Sampaio, D; Breier, TB'], "Carboni, M; Faraco, AG; Soares, P.G.; Sampaio, D; Breier, TB"),
    (['Silva; D.R.; Colvéquia; L.P.T'], "Silva, D.R.; Colvéquia, L.P.T"),
    (['Quintiliano; F.J.; Colvéquia; L.P.T; Silva; D.R.'], "Quintiliano, F.J.; Colvéquia, L.P.T; Silva, D.R."),
    
    (['Yushun.; K.', 
      'Barbosa; M.G.'], 
            lambda x: x.replace(';',',')
    ),   
]

atomizingFunction = lambda x: nc.namesFromString(x,delim=';') 
atomized_recordedBy = atomizeNames(occs['recordedBy'],operation=atomizingFunction, replaces=rep)
occs['recordedBy_atomized'] = atomized_recordedBy
occs_collaborative = occs[occs['recordedBy_atomized'].apply(lambda x: len(x)>1)]

# %%
occs_collaborative.head()
# Out:
#    collectionCode                             recordedBy  \
# 1              UB                     Ratter, JA; et al.
# 4              UB                    Eiten, G; Eiten, LT
# 7              UB  Proença, CEB; Oliveira, RS; Pinto, AS
# 9              UB       Gomes, BM; Brito, DS; Mendes, VC
# 11             UB                Montgomery, F; Blake, D
#
#                    scientificName taxonRank  \
# 1   Myracrodruon urundeuva Allem.   SPECIES
# 4   Myracrodruon urundeuva Allem.   SPECIES
# 7              Ichthyothere Mart.     GENUS
# 9             Bromelia exigua Mez   SPECIES
# 11       Nyssa sylvatica Marshall   SPECIES
#
#                         recordedBy_atomized
# 1                      [Ratter, JA, et al.]
# 4                     [Eiten, G, Eiten, LT]
# 7   [Proença, CEB, Oliveira, RS, Pinto, AS]
# 9        [Gomes, BM, Brito, DS, Mendes, VC]
# 11                [Montgomery, F, Blake, D]

# %% [markdown]
# ## Building names map

# %%
nl = getNamesList(occs['recordedBy_atomized'], orderBy="alphabetic")
nm = nc.NamesMap(nl, nc.normalize)

# %%
nm.getMap()
# Out:
# {'.': '',
#  '1980 Sino-Amer Exped.': 'sinoamerexped',
#  '?': '',
#  'A.J.N.V.': 'ajnv',
#  'A.M.': 'am',
#  'Abbas, B': 'abbas,b',
#  'Abdala, GC': 'abdala,gc',
#  'Abdo, MSA': 'abdo,msa',
#  'Abdon': 'abdon',
#  'Abe, LB': 'abe,lb',
#  'Abe, LM': 'abe,lm',
#  'Abrahim, MA': 'abrahim,ma',
#  'Abreu, CG': 'abreu,cg',
#  'Abreu, GX': 'abreu,gx',
#  'Abreu, I': 'abreu,i',
#  'Abreu, LC': 'abreu,lc',
#  'Abreu, LCR': 'abreu,lcr',
#  'Abreu, M': 'abreu,m',
#  'Abreu, MC': 'abreu,mc',
#  'Abreu, MS': 'abreu,ms',
#  'Abreu, NL': 'abreu,nl',
#  'Abreu, NR': 'abreu,nr',
#  'Abreu, TLS': 'abreu,tls',
#  'Accioly': 'accioly',
#  'Accorsi, WR': 'accorsi,wr',
#  'Acera, V': 'acera,v',
#  'Acevedo-Rodriguez, P': 'acevedorodriguez,p',
#  'Acuña, BC': 'acuna,bc',
#  'Adams, WP': 'adams,wp',
#  'Adcock, S': 'adcock,s',
#  'Adderley, LS': 'adderley,ls',
#  'Addison, G': 'addison,g',
#  'Addor, EE': 'addor,ee',
#  'Adler': 'adler',
#  'Adorno, H': 'adorno,h',
#  'Adão': 'adao',
#  'Aedo, C': 'aedo,c',
#  'Affonso, P': 'affonso,p',
#  'Afonso, AA': 'afonso,aa',
#  'Afonso, AP': 'afonso,ap',
#  'Agenor': 'agenor',
#  'Aguiar, AC': 'aguiar,ac',
#  'Aguiar, ACA': 'aguiar,aca',
#  'Aguiar, AJC': 'aguiar,ajc',
#  'Aguiar, AM': 'aguiar,am',
#  'Aguiar, AN': 'aguiar,an',
#  'Aguiar, C': 'aguiar,c',
#  'Aguiar, E': 'aguiar,e',
#  'Aguiar, OT': 'aguiar,ot',
#  'Aguiar, P': 'aguiar,p',
#  'Aguiar, SNF': 'aguiar,snf',
#  'Aguilar, R': 'aguilar,r',
#  'Aguirre, GH': 'aguirre,gh',
#  'Ahti, T': 'ahti,t',
#  'Ahumada, Z': 'ahumada,z',
#  'Aires, CA': 'aires,ca',
#  'Aires, DA': 'aires,da',
#  'Aires, J': 'aires,j',
#  'Aires, RC': 'aires,rc',
#  'Aires, SL': 'aires,sl',
#  'Akisul, G': 'akisul,g',
#  'Akiyama, H': 'akiyama,h',
#  'Alain': 'alain',
#  'Alamo, FG': 'alamo,fg',
#  'Alava, A': 'alava,a',
#  'Alava, R': 'alava,r',
#  'Alavarenga, D': 'alavarenga,d',
#  'Albiero, A': 'albiero,a',
#  'Albino, BV': 'albino,bv',
#  'Albino, RS': 'albino,rs',
#  'Albright, R': 'albright,r',
#  'Albuquerque, BWP': 'albuquerque,bwp',
#  'Albuquerque, JM': 'albuquerque,jm',
#  'Albuquerque, M': 'albuquerque,m',
#  'Albuquerque, V': 'albuquerque,v',
#  'Albuquerque, VBA': 'albuquerque,vba',
#  'Albuquerque, VR': 'albuquerque,vr',
#  'Alcina': 'alcina',
#  'Alcock, CR': 'alcock,cr',
#  'Alcoforado Filho, FG': 'alcoforadofilho,fg',
#  'Alcântara': 'alcantara',
#  'Alcântara, MB': 'alcantara,mb',
#  'Alcântara, TH': 'alcantara,th',
#  'Alecrim, MC': 'alecrim,mc',
#  'Aleixo, R': 'aleixo,r',
#  'Alencar, A': 'alencar,a',
#  'Alencar, KMC': 'alencar,kmc',
#  'Alencar, L': 'alencar,l',
#  'Alencar, ME': 'alencar,me',
#  'Alencar, T': 'alencar,t',
#  'Alencastro, A': 'alencastro,a',
#  'Alessandro': 'alessandro',
#  'Alexandre, MT': 'alexandre,mt',
#  'Alfaro, E': 'alfaro,e',
#  'Alho, K': 'alho,k',
#  'Alho, R': 'alho,r',
#  'Aline': 'aline',
#  'Alkimim, W': 'alkimim,w',
#  'Allan, KM': 'allan,km',
#  'Allard, HA': 'allard,ha',
#  'Allem, A': 'allem,a',
#  'Allem, AC': 'allem,ac',
#  'Allem, LN': 'allem,ln',
#  'Allen, B': 'allen,b',
#  'Allen, GH': 'allen,gh',
#  'Allen, JA': 'allen,ja',
#  'Allender, MJ': 'allender,mj',
#  'Allevato, SR': 'allevato,sr',
#  'Allorge, L': 'allorge,l',
#  'Almeda, F': 'almeda,f',
#  'Almeida, AA': 'almeida,aa',
#  'Almeida, C': 'almeida,c',
#  'Almeida, COS': 'almeida,cos',
#  'Almeida, EF': 'almeida,ef',
#  'Almeida, F': 'almeida,f',
#  'Almeida, FC': 'almeida,fc',
#  'Almeida, FM': 'almeida,fm',
#  'Almeida, GEM': 'almeida,gem',
#  'Almeida, GSC': 'almeida,gsc',
#  'Almeida, J': 'almeida,j',
#  'Almeida, JC': 'almeida,jc',
#  'Almeida, JGL': 'almeida,jgl',
#  'Almeida, JV': 'almeida,jv',
#  'Almeida, L': 'almeida,l',
#  'Almeida, LP': 'almeida,lp',
#  'Almeida, M': 'almeida,m',
#  'Almeida, MC': 'almeida,mc',
#  'Almeida, MIQ': 'almeida,miq',
#  'Almeida, MR': 'almeida,mr',
#  'Almeida, RC': 'almeida,rc',
#  'Almeida, RE': 'almeida,re',
#  'Almeida, RF': 'almeida,rf',
#  'Almeida, RJ': 'almeida,rj',
#  'Almeida, S': 'almeida,s',
#  'Almeida, SMS': 'almeida,sms',
#  'Almeida, SP': 'almeida,sp',
#  'Almeida, SS': 'almeida,ss',
#  'Almeida, TE': 'almeida,te',
#  'Almeida, VR': 'almeida,vr',
#  'Almeida-Scabbia, RJ': 'almeidascabbia,rj',
#  'Aloisi, J': 'aloisi,j',
#  'Alreo, M': 'alreo,m',
#  'Altamiro': 'altamiro',
#  'Althoff, KC': 'althoff,kc',
#  'Alunos Bot III': 'alunosbotiii',
#  'Alunos de Biologia IV': 'alunosdebiologiaiv',
#  'Alunos de Sistemática Vegetal': 'alunosdesistematicavegetal',
#  'Alvarenga, A': 'alvarenga,a',
#  'Alvarenga, D': 'alvarenga,d',
#  'Alvarenga, FG': 'alvarenga,fg',
#  'Alvarenga, L': 'alvarenga,l',
#  'Alvarenga, M': 'alvarenga,m',
#  'Alves Júnior, C': 'alvesjunior,c',
#  'Alves, AF': 'alves,af',
#  'Alves, AG': 'alves,ag',
#  'Alves, AS': 'alves,as',
#  'Alves, ASA': 'alves,asa',
#  'Alves, CA': 'alves,ca',
#  'Alves, FM': 'alves,fm',
#  'Alves, FQ': 'alves,fq',
#  'Alves, GKJ': 'alves,gkj',
#  'Alves, H': 'alves,h',
#  'Alves, J': 'alves,j',
#  'Alves, JH': 'alves,jh',
#  'Alves, JLH': 'alves,jlh',
#  'Alves, L': 'alves,l',
#  'Alves, LC': 'alves,lc',
#  'Alves, LF': 'alves,lf',
#  'Alves, LM': 'alves,lm',
#  'Alves, LQ': 'alves,lq',
#  'Alves, M': 'alves,m',
#  'Alves, MA': 'alves,ma',
#  'Alves, MAS': 'alves,mas',
#  'Alves, MC': 'alves,mc',
#  'Alves, MM': 'alves,mm',
#  'Alves, MV': 'alves,mv',
#  'Alves, PD': 'alves,pd',
#  'Alves, RBN': 'alves,rbn',
#  'Alves, RNB': 'alves,rnb',
#  'Alves, RR': 'alves,rr',
#  'Alves, RU': 'alves,ru',
#  'Alves, SAM': 'alves,sam',
#  'Alves, SRT': 'alves,srt',
#  'Alves, T': 'alves,t',
#  'Alvim, LC': 'alvim,lc',
#  'Alvim, MB': 'alvim,mb',
#  'Alvin, P': 'alvin,p',
#  'Amado, TF': 'amado,tf',
#  'Amador, DB': 'amador,db',
#  'Amaral Júnior, A': 'amaraljunior,a',
#  'Amaral, A': 'amaral,a',
#  'Amaral, AC': 'amaral,ac',
#  'Amaral, AF': 'amaral,af',
#  'Amaral, AG': 'amaral,ag',
#  'Amaral, AS': 'amaral,as',
#  'Amaral, BR': 'amaral,br',
#  'Amaral, E': 'amaral,e',
#  'Amaral, IL': 'amaral,il',
#  'Amaral, JP': 'amaral,jp',
#  'Amaral, LG': 'amaral,lg',
#  'Amaral, MC': 'amaral,mc',
#  'Amaral, MCE': 'amaral,mce',
#  'Amaral, MF': 'amaral,mf',
#  'Amaral, RC': 'amaral,rc',
#  'Amaral, TS': 'amaral,ts',
#  'Amaral, WAN': 'amaral,wan',
#  'Amaury': 'amaury',
#  'Amdursky, I': 'amdursky,i',
#  'Amenomori, SN': 'amenomori,sn',
#  'Amorim Neto, L': 'amorimneto,l',
#  'Amorim, A': 'amorim,a',
#  'Amorim, AH': 'amorim,ah',
#  'Amorim, AM': 'amorim,am',
#  'Amorim, AMA': 'amorim,ama',
#  'Amorim, EH': 'amorim,eh',
#  'Amorim, L': 'amorim,l',
#  'Amorim, ME': 'amorim,me',
#  'Amorim, P': 'amorim,p',
#  'Amorim, PR': 'amorim,pr',
#  'Amorim, PRF': 'amorim,prf',
#  'Amorim, SF': 'amorim,sf',
#  'Ana': 'ana',
#  'Ana Angélica': 'anaangelica',
#  'Ana Clara': 'anaclara',
#  'Ana Luíza': 'analuiza',
#  'Ana Paula': 'anapaula',
#  'Ana, Lima': 'ana,lima',
#  'Anael': 'anael',
#  'Anastacio': 'anastacio',
#  'Ancelmo': 'ancelmo',
#  'Andahur, JP': 'andahur,jp',
#  'Anderson, C': 'anderson,c',
#  'Anderson, H': 'anderson,h',
#  'Anderson, HS': 'anderson,hs',
#  'Anderson, JL': 'anderson,jl',
#  'Anderson, L': 'anderson,l',
#  'Anderson, LE': 'anderson,le',
#  'Anderson, P': 'anderson,p',
#  'Anderson, W': 'anderson,w',
#  'Anderson, WR': 'anderson,wr',
#  'Andersson, L': 'andersson,l',
#  'Ando, N': 'ando,n',
#  'Andrade, A': 'andrade,a',
#  'Andrade, AM': 'andrade,am',
#  'Andrade, BS': 'andrade,bs',
#  'Andrade, CCA': 'andrade,cca',
#  'Andrade, CT': 'andrade,ct',
#  'Andrade, JB': 'andrade,jb',
#  'Andrade, JC': 'andrade,jc',
#  'Andrade, KA': 'andrade,ka',
#  'Andrade, LAA': 'andrade,laa',
#  'Andrade, LAZ': 'andrade,laz',
#  'Andrade, LD': 'andrade,ld',
#  'Andrade, MAR': 'andrade,mar',
#  'Andrade, MC': 'andrade,mc',
#  'Andrade, MD': 'andrade,md',
#  'Andrade, MJG': 'andrade,mjg',
#  'Andrade, NF': 'andrade,nf',
#  'Andrade, P': 'andrade,p',
#  'Andrade, PM': 'andrade,pm',
#  'Andrade, S': 'andrade,s',
#  'Andrade, SF': 'andrade,sf',
#  'Andrade, SMM': 'andrade,smm',
#  'Andrade-Lima, D': 'andradelima,d',
#  'Andrea': 'andrea',
#  'Andrea, M': 'andrea,m',
#  'Andrelinho': 'andrelinho',
#  'Andrews, HH': 'andrews,hh',
#  'Andrikopoll, F': 'andrikopoll,f',
#  'André': 'andre',
#  'Angarten, NBO': 'angarten,nbo',
#  'Angeli, C': 'angeli,c',
#  'Angélica': 'angelica',
#  'Anhanguera, UL': 'anhanguera,ul',
#  'Anjos, ER': 'anjos,er',
#  'Anjos, JRN': 'anjos,jrn',
#  'Anjos, VC': 'anjos,vc',
#  'Annunziata, BB': 'annunziata,bb',
#  'Antezana, FL': 'antezana,fl',
#  'Antonio': 'antonio',
#  'Antonio, T': 'antonio,t',
#  'Antonio, TM': 'antonio,tm',
#  'Antoniolli, FC': 'antoniolli,fc',
#  'Antunes, EC': 'antunes,ec',
#  'Antunes, J': 'antunes,j',
#  'Antunes, K': 'antunes,k',
#  'Antunes, LL': 'antunes,ll',
#  'Antunes, LLC': 'antunes,llc',
#  'Antunes, NB': 'antunes,nb',
#  'Antunes, RM': 'antunes,rm',
#  'Antônio, M': 'antonio,m',
#  'Anunciação, AE': 'anunciacao,ae',
#  'Aona, LYS': 'aona,lys',
#  'Aparecida da Silva, M': 'aparecidadasilva,m',
#  'Aplin, TEH': 'aplin,teh',
#  'Aponte, CH': 'aponte,ch',
#  'Apparício': 'apparicio',
#  'Aquilante, DJ': 'aquilante,dj',
#  'Aquino, C': 'aquino,c',
#  'Aquino, F': 'aquino,f',
#  'Aquino, FG': 'aquino,fg',
#  'Aquino, M': 'aquino,m',
#  'Aquino, PAN': 'aquino,pan',
#  'Aquino, PPU': 'aquino,ppu',
#  'Aquino, PPV': 'aquino,ppv',
#  'Aquino, R': 'aquino,r',
#  'Arae, F': 'arae,f',
#  'Aragaki, S': 'aragaki,s',
#  'Aragona, L': 'aragona,l',
#  'Aragona, M': 'aragona,m',
#  'Aragone': 'aragone',
#  'Aragão, F': 'aragao,f',
#  'Aragão, I': 'aragao,i',
#  'Aragão, JG': 'aragao,jg',
#  'Araki, DF': 'araki,df',
#  'Aranha Filho, JLM': 'aranhafilho,jlm',
#  'Aranha, BA': 'aranha,ba',
#  'Aranha, C': 'aranha,c',
#  'Arantes, A': 'arantes,a',
#  'Arantes, AA': 'arantes,aa',
#  'Arantes, C': 'arantes,c',
#  'Araujo, AC': 'araujo,ac',
#  'Araujo, AG': 'araujo,ag',
#  'Araujo, AO': 'araujo,ao',
#  'Araujo, GB': 'araujo,gb',
#  'Araujo, GM': 'araujo,gm',
#  'Araujo, J': 'araujo,j',
#  'Araujo, RC': 'araujo,rc',
#  'Araujo, S': 'araujo,s',
#  'Araújo, AFB': 'araujo,afb',
#  'Araújo, AFP': 'araujo,afp',
#  'Araújo, AG': 'araujo,ag',
#  'Araújo, AMS': 'araujo,ams',
#  'Araújo, AO': 'araujo,ao',
#  'Araújo, AP': 'araujo,ap',
#  'Araújo, CM': 'araujo,cm',
#  'Araújo, CO': 'araujo,co',
#  'Araújo, CSF': 'araujo,csf',
#  'Araújo, D': 'araujo,d',
#  'Araújo, DA': 'araujo,da',
#  'Araújo, DSD': 'araujo,dsd',
#  'Araújo, F': 'araujo,f',
#  'Araújo, FD': 'araujo,fd',
#  'Araújo, FP': 'araujo,fp',
#  'Araújo, FS': 'araujo,fs',
#  'Araújo, G': 'araujo,g',
#  'Araújo, GM': 'araujo,gm',
#  'Araújo, GP': 'araujo,gp',
#  'Araújo, GS': 'araujo,gs',
#  'Araújo, I': 'araujo,i',
#  'Araújo, JE': 'araujo,je',
#  'Araújo, JS': 'araujo,js',
#  'Araújo, LH': 'araujo,lh',
#  'Araújo, LM': 'araujo,lm',
#  'Araújo, M': 'araujo,m',
#  'Araújo, MF': 'araujo,mf',
#  'Araújo, MI': 'araujo,mi',
#  'Araújo, RF': 'araujo,rf',
#  'Araújo, RS': 'araujo,rs',
#  'Araújo, SC': 'araujo,sc',
#  'Araújo, TF': 'araujo,tf',
#  'Araújo, TOP': 'araujo,top',
#  'Araújo, WS': 'araujo,ws',
#  'Arbelaez, EP': 'arbelaez,ep',
#  'Arbex, LH': 'arbex,lh',
#  'Arbo, MM': 'arbo,mm',
#  'Arcanjo Pinheiro': 'arcanjopinheiro',
#  'Arcanjo, D': 'arcanjo,d',
#  'Arcanjo, M': 'arcanjo,m',
#  'Arcela, V': 'arcela,v',
#  'Archer, W': 'archer,w',
#  'Archer, WA': 'archer,wa',
#  'Archer, WH': 'archer,wh',
#  'Areias, CA': 'areias,ca',
#  'Areira, J': 'areira,j',
#  'Argent G.C.G.': 'argentgcg',
#  'Argent G.C.G. in': 'argentgcgin',
#  'Argent, G': 'argent,g',
#  'Argent, GCG': 'argent,gcg',
#  'Arima, EY': 'arima,ey',
#  'Arima, LIA': 'arima,lia',
#  'Arimoro, O': 'arimoro,o',
#  'Aristeguieta, L': 'aristeguieta,l',
#  'Arlindo': 'arlindo',
#  'Armando, M': 'armando,m',
#  'Armando, MS': 'armando,ms',
#  'Armbruster, WS': 'armbruster,ws',
#  'Arnaldo': 'arnaldo',
#  'Arnell, HW': 'arnell,hw',
#  'Arnold': 'arnold',
#  'Arnold, T': 'arnold,t',
#  'Arouck, J': 'arouck,j',
#  'Arraes, MG': 'arraes,mg',
#  'Arraes, MGM': 'arraes,mgm',
#  'Arrais, MGM': 'arrais,mgm',
#  'Arroyo': 'arroyo',
#  'Arroyo, MTK': 'arroyo,mtk',
#  'Arruda, AJ': 'arruda,aj',
#  'Arruda, EC': 'arruda,ec',
#  'Arruda, ML': 'arruda,ml',
#  'Arruda, MLR': 'arruda,mlr',
#  'Arruda, R': 'arruda,r',
#  'Arruda, VR': 'arruda,vr',
#  'Arruda, WS': 'arruda,ws',
#  'Arsene': 'arsene',
#  'Arts, T': 'arts,t',
#  'Arvher, W': 'arvher,w',
#  'Arzolla, FARDP': 'arzolla,fardp',
#  'Arzolla, FARP': 'arzolla,farp',
#  'Ascendino, AA': 'ascendino,aa',
#  'Aschan, N': 'aschan,n',
#  'Ashlee, TR': 'ashlee,tr',
#  'Ashton, EM': 'ashton,em',
#  'Assis, A': 'assis,a',
#  'Assis, AM': 'assis,am',
#  'Assis, CM': 'assis,cm',
#  'Assis, JS': 'assis,js',
#  'Assis, LCS': 'assis,lcs',
#  'Assis, M': 'assis,m',
#  'Assis, MA': 'assis,ma',
#  'Assis, MC': 'assis,mc',
#  'Assis, TS': 'assis,ts',
#  'Assis, V': 'assis,v',
#  'Assumpção, D': 'assumpcao,d',
#  'Assumpção, S': 'assumpcao,s',
#  'Assunsão, MM': 'assunsao,mm',
#  'Assunsão, PACI': 'assunsao,paci',
#  'Assunção, PA': 'assuncao,pa',
#  'Assunção, PACL': 'assuncao,pacl',
#  'Assunção, PACS': 'assuncao,pacs',
#  'Assunção, S': 'assuncao,s',
#  'Assunção, V': 'assuncao,v',
#  'Assunção, VA': 'assuncao,va',
#  'Astle, WL': 'astle,wl',
#  'Astorino, A': 'astorino,a',
#  'Atala, F': 'atala,f',
#  'Atayde, P': 'atayde,p',
#  'Ataíde, M': 'ataide,m',
#  'Athaide, P': 'athaide,p',
#  'Athayde Filho, FP': 'athaydefilho,fp',
#  'Atkins, S': 'atkins,s',
#  'Atkinson, R': 'atkinson,r',
#  'Atta, ALV': 'atta,alv',
#  'Atta, AVL': 'atta,avl',
#  'Attala, NC': 'attala,nc',
#  'Atwood, J': 'atwood,j',
#  'Auad, MV': 'auad,mv',
#  'Aubreville, A': 'aubreville,a',
#  'Audenis, C': 'audenis,c',
#  'Auer, AV': 'auer,av',
#  'Augusto, J': 'augusto,j',
#  'Augusto, MM': 'augusto,mm',
#  'Aulino, O': 'aulino,o',
#  'Aura, A': 'aura,a',
#  'Aurélio': 'aurelio',
#  'Aurélio Silva, M': 'aureliosilva,m',
#  'Avelar, MG': 'avelar,mg',
#  'Avelar, P': 'avelar,p',
#  'Avila, MV': 'avila,mv',
#  'Ayala, F': 'ayala,f',
#  'Ayansu': 'ayansu',
#  'Ayedem, N': 'ayedem,n',
#  'Ayre, AM': 'ayre,am',
#  'Azevedo': 'azevedo',
#  'Azevedo, AA': 'azevedo,aa',
#  'Azevedo, D': 'azevedo,d',
#  'Azevedo, EP': 'azevedo,ep',
#  'Azevedo, F': 'azevedo,f',
#  'Azevedo, GR': 'azevedo,gr',
#  'Azevedo, IM': 'azevedo,im',
#  'Azevedo, INC': 'azevedo,inc',
#  'Azevedo, MLM': 'azevedo,mlm',
#  'Azevedo, V': 'azevedo,v',
#  'Bacci, LF': 'bacci,lf',
#  'Bach, J': 'bach,j',
#  'Badcock': 'badcock',
#  'Badini, J': 'badini,j',
#  'Baeza, CM': 'baeza,cm',
#  'Baeza, P': 'baeza,p',
#  'Bagalhi, E': 'bagalhi,e',
#  'Bagato, D': 'bagato,d',
#  'Bahia, RP': 'bahia,rp',
#  'Bahia, TR': 'bahia,tr',
#  'Bailey, FM': 'bailey,fm',
#  'Bailey, WM': 'bailey,wm',
#  'Baitello, JB': 'baitello,jb',
#  'Baker, J': 'baker,j',
#  'Baker, JG': 'baker,jg',
#  'Baker, MS': 'baker,ms',
#  'Balbino, V': 'balbino,v',
#  'Balbuena, C': 'balbuena,c',
#  'Baldwin Junior, JT': 'baldwinjunior,jt',
#  'Baleeiro, P': 'baleeiro,p',
#  'Balegno, B': 'balegno,b',
#  'Balfour': 'balfour',
#  'Balgooy, MMJ': 'balgooy,mmj',
#  'Balick, MJ': 'balick,mj',
#  'Balslev, H': 'balslev,h',
#  'Baltzell, L': 'baltzell,l',
#  'Bandeira, FP': 'bandeira,fp',
#  'Bankoff, P': 'bankoff,p',
#  'Bao, F': 'bao,f',
#  'Baptista, CB': 'baptista,cb',
#  'Baptista, MLL': 'baptista,mll',
#  'Baracat, C': 'baracat,c',
#  'Baracot, C': 'baracot,c',
#  'Baracot, LCH': 'baracot,lch',
#  'Barahona, E': 'barahona,e',
#  'Barbarioli Neto, M': 'barbariolineto,m',
#  'Barbaro, D': 'barbaro,d',
#  'Barbiellini, AA': 'barbiellini,aa',
#  'Barbosa': 'barbosa',
#  'Barbosa Rodrigues, S': 'barbosarodrigues,s',
#  'Barbosa, A': 'barbosa,a',
#  'Barbosa, AA': 'barbosa,aa',
#  'Barbosa, AAA': 'barbosa,aaa',
#  'Barbosa, ACF': 'barbosa,acf',
#  'Barbosa, AM': 'barbosa,am',
#  'Barbosa, AR': 'barbosa,ar',
#  'Barbosa, C': 'barbosa,c',
#  'Barbosa, E': 'barbosa,e',
#  'Barbosa, EA': 'barbosa,ea',
#  'Barbosa, HN': 'barbosa,hn',
#  'Barbosa, J': 'barbosa,j',
#  'Barbosa, JC': 'barbosa,jc',
#  'Barbosa, JM': 'barbosa,jm',
#  'Barbosa, JP': 'barbosa,jp',
#  'Barbosa, LF': 'barbosa,lf',
#  'Barbosa, LMQ': 'barbosa,lmq',
#  'Barbosa, M': 'barbosa,m',
#  'Barbosa, M.G.': 'barbosa,mg',
#  'Barbosa, MA': 'barbosa,ma',
#  'Barbosa, MM': 'barbosa,mm',
#  'Barbosa, MR': 'barbosa,mr',
#  'Barbosa, NF': 'barbosa,nf',
#  'Barbosa, NM': 'barbosa,nm',
#  'Barbosa, T': 'barbosa,t',
#  'Barbosa, VP': 'barbosa,vp',
#  'Barbosa-Silva, D': 'barbosasilva,d',
#  'Barboza, C': 'barboza,c',
#  'Barboza, E': 'barboza,e',
#  'Barboza, EA': 'barboza,ea',
#  'Barboza, MA': 'barboza,ma',
#  'Barcia, J': 'barcia,j',
#  'Bardelli, KC': 'bardelli,kc',
#  'Barghoorn, E': 'barghoorn,e',
#  'Barino, GTM': 'barino,gtm',
#  'Barker, R': 'barker,r',
#  'Barker, RM': 'barker,rm',
#  'Barneby, R': 'barneby,r',
#  'Barneby, RC': 'barneby,rc',
#  'Barreto, ACC': 'barreto,acc',
#  'Barreto, D': 'barreto,d',
#  'Barreto, HLM': 'barreto,hlm',
#  'Barreto, KD': 'barreto,kd',
#  'Barreto, LAS': 'barreto,las',
#  'Barreto, LVF': 'barreto,lvf',
#  'Barreto, M': 'barreto,m',
#  'Barreto, MLA': 'barreto,mla',
#  'Barreto, R': 'barreto,r',
#  'Barreto, V': 'barreto,v',
#  'Barreto, VC': 'barreto,vc',
#  'Barros, A': 'barros,a',
#  'Barros, AG': 'barros,ag',
#  'Barros, AL': 'barros,al',
#  'Barros, BS': 'barros,bs',
#  'Barros, C': 'barros,c',
#  'Barros, CRMB': 'barros,crmb',
#  'Barros, F': 'barros,f',
#  'Barros, G': 'barros,g',
#  'Barros, GV': 'barros,gv',
#  'Barros, ICL': 'barros,icl',
#  'Barros, JS': 'barros,js',
#  'Barros, LAC': 'barros,lac',
#  'Barros, LES': 'barros,les',
#  'Barros, M': 'barros,m',
#  'Barros, MAG': 'barros,mag',
#  'Barros, MLS': 'barros,mls',
#  'Barros, NM': 'barros,nm',
#  'Barros, R': 'barros,r',
#  'Barros, S': 'barros,s',
#  'Barros, WD': 'barros,wd',
#  'Barroso, GM': 'barroso,gm',
#  'Barroso, JEM': 'barroso,jem',
#  'Barssukowa, A': 'barssukowa,a',
#  'Barter': 'barter',
#  'Barth, J': 'barth,j',
#  'Bartil, A': 'bartil,a',
#  'Bartlett, HH': 'bartlett,hh',
#  'Bartolomeu, ACD': 'bartolomeu,acd',
#  'Bartolomeu, J': 'bartolomeu,j',
#  'Bartolomeu, JG': 'bartolomeu,jg',
#  'Bartolotto, IM': 'bartolotto,im',
#  'Basso, F': 'basso,f',
#  'Basso, ME': 'basso,me',
#  'Bastianon, CVT': 'bastianon,cvt',
#  'Bastos (D. Preta), MAG': 'bastosdpreta,mag',
#  'Bastos Neto, OJ': 'bastosneto,oj',
#  'Bastos, AM': 'bastos,am',
#  'Bastos, BC': 'bastos,bc',
#  'Bastos, C': 'bastos,c',
#  'Bastos, CJP': 'bastos,cjp',
#  'Bastos, EB': 'bastos,eb',
#  'Bastos, EK': 'bastos,ek',
#  'Bastos, HM': 'bastos,hm',
#  'Bastos, JAA': 'bastos,jaa',
#  'Bastos, K': 'bastos,k',
#  'Bastos, M': 'bastos,m',
#  'Bastos, MFB': 'bastos,mfb',
#  'Bastos, N': 'bastos,n',
#  'Bastos, OJ': 'bastos,oj',
#  'Batalha, MA': 'batalha,ma',
#  'Batista, AC': 'batista,ac',
#  'Batista, AM': 'batista,am',
#  'Batista, CR': 'batista,cr',
#  'Batista, DF': 'batista,df',
#  'Batista, ER': 'batista,er',
#  'Batista, G': 'batista,g',
#  'Batista, GO': 'batista,go',
#  'Batista, GS': 'batista,gs',
#  'Batista, JAN': 'batista,jan',
#  'Batista, LBC': 'batista,lbc',
#  'Batista, MA': 'batista,ma',
#  'Batista, ML': 'batista,ml',
#  'Batista, MMF': 'batista,mmf',
#  'Batista, NTF': 'batista,ntf',
#  'Batista, R': 'batista,r',
#  'Batmanian, FJ': 'batmanian,fj',
#  'Batmanian, G': 'batmanian,g',
#  'Bauer, E': 'bauer,e',
#  'Bauerlen, W': 'bauerlen,w',
#  'Baumgarten, J': 'baumgarten,j',
#  'Baumgartz, JFA': 'baumgartz,jfa',
#  'Baumgratz, JFA': 'baumgratz,jfa',
#  'Baungarten, J': 'baungarten,j',
#  'Bausen, E': 'bausen,e',
#  'Bautista, HP': 'bautista,hp',
#  'Bazarian, SV': 'bazarian,sv',
#  'Baéz, P': 'baez,p',
#  'Bean, MF': 'bean,mf',
#  'Beatriz, MC': 'beatriz,mc',
#  'Beaupertuis': 'beaupertuis',
#  'Beccari, O': 'beccari,o',
#  'Beck, B': 'beck,b',
#  'Beck, G': 'beck,g',
#  'Beck, S': 'beck,s',
#  'Beck, StG': 'beck,stg',
#  'Becker, RM': 'becker,rm',
#  'Becker, VO': 'becker,vo',
#  'Bedim, A': 'bedim,a',
#  'Belchior, V': 'belchior,v',
#  'Belgrano, M': 'belgrano,m',
#  'Belinello, R': 'belinello,r',
#  'Belisario, M': 'belisario,m',
#  'Belizário, M': 'belizario,m',
#  'Belk, E': 'belk,e',
#  'Belko, T': 'belko,t',
#  'Bell, BG': 'bell,bg',
#  'Bell, RQ': 'bell,rq',
#  'Bello, JF': 'bello,jf',
#  'Bellolio, G': 'bellolio,g',
#  'Bellwinkel': 'bellwinkel',
#  'Belmok, LE': 'belmok,le',
#  'Beltrão, L': 'beltrao,l',
#  'Belém, PR': 'belem,pr',
#  'Belém, RP': 'belem,rp',
#  'Ben': 'ben',
#  'Bencke, CSC': 'bencke,csc',
#  'Benedet, AL': 'benedet,al',
#  'Benedete': 'benedete',
#  'Benedete, AL': 'benedete,al',
#  'Benedetti, FJ': 'benedetti,fj',
#  'Benedito, GSR': 'benedito,gsr',
#  'Benini, RM': 'benini,rm',
#  'Beninni, ST': 'beninni,st',
#  'Bennett, EM': 'bennett,em',
#  'Bennett, HR': 'bennett,hr',
#  'Benoliel, B': 'benoliel,b',
#  'Benson, D': 'benson,d',
#  'Benson, JL': 'benson,jl',
#  'Benson, WW': 'benson,ww',
#  'Bensusan, N': 'bensusan,n',
#  'Bensusan, NR': 'bensusan,nr',
#  'Bentley, MS': 'bentley,ms',
#  'Bento, LSRN': 'bento,lsrn',
#  'Bento, MS': 'bento,ms',
#  'Benton, F': 'benton,f',
#  'Benton, FP': 'benton,fp',
#  'Benício': 'benicio',
#  'Berg, CC': 'berg,cc',
#  'Bergalli': 'bergalli',
#  'Bergamini, LL': 'bergamini,ll',
#  'Berger, A': 'berger,a',
#  'Bergo, NM': 'bergo,nm',
#  'Bergossi, AM': 'bergossi,am',
#  'Bernabé, MJC': 'bernabe,mjc',
#  'Bernacci, LC': 'bernacci,lc',
#  'Bernacci, M': 'bernacci,m',
#  'Bernadete': 'bernadete',
#  'Bernadino, J': 'bernadino,j',
#  'Bernal, RA': 'bernal,ra',
#  'Bernardes, C': 'bernardes,c',
#  'Bernardes, CB': 'bernardes,cb',
#  'Bernardes, PHN': 'bernardes,phn',
#  'Bernardino, J': 'bernardino,j',
#  'Bernardo, CM': 'bernardo,cm',
#  'Bernasol, WP': 'bernasol,wp',
#  'Bernd, RB': 'bernd,rb',
#  'Bernhardt, R': 'bernhardt,r',
#  'Bertanha, WFF': 'bertanha,wff',
#  'Bertani, DF': 'bertani,df',
#  'Bertazzoni, EC': 'bertazzoni,ec',
#  'Berto, ACV': 'berto,acv',
#  'Bertocini, AP': 'bertocini,ap',
#  'Bertolda, J': 'bertolda,j',
#  'Bertoldo, J': 'bertoldo,j',
#  'Bertoli, AG': 'bertoli,ag',
#  'Bertoncini, AP': 'bertoncini,ap',
#  'Bertoni, JEA': 'bertoni,jea',
#  'Berçot, ACS': 'bercot,acs',
#  'Berçot, C': 'bercot,c',
#  'Bessa, MA': 'bessa,ma',
#  'Bessa, RS': 'bessa,rs',
#  'Bessler, H': 'bessler,h',
#  'Betche, E': 'betche,e',
#  'Beusekom, V': 'beusekom,v',
#  'Beyer, C': 'beyer,c',
#  'Bezerra, A': 'bezerra,a',
#  'Bezerra, CLF': 'bezerra,clf',
#  'Bezerra, KMG': 'bezerra,kmg',
#  'Bezerra, LFD': 'bezerra,lfd',
#  'Bezerra, M': 'bezerra,m',
#  'Bezerra, MG': 'bezerra,mg',
#  'Bezerra, P': 'bezerra,p',
#  'Bezerra, REP': 'bezerra,rep',
#  'Bhagirathi, S': 'bhagirathi,s',
#  'Biagi, F': 'biagi,f',
#  'Bianca, AM': 'bianca,am',
#  'Bianchetti, L': 'bianchetti,l',
#  'Bianchetti, LB': 'bianchetti,lb',
#  'Bianchi, C': 'bianchi,c',
#  'Bianchini, E': 'bianchini,e',
#  'Bianchini, RS': 'bianchini,rs',
#  'Biavati, GM': 'biavati,gm',
#  'Bicalho, H': 'bicalho,h',
#  'Bicudo, LRH': 'bicudo,lrh',
#  'Bicudo, PL': 'bicudo,pl',
#  'Bid': 'bid',
#  'Bidá, A': 'bida,a',
#  'Biernaski': 'biernaski',
#  'Biese, W': 'biese,w',
#  'Bieski, I': 'bieski,i',
#  'Biggs, N': 'biggs,n',
#  'Bijos, NR': 'bijos,nr',
#  'Bilby, R': 'bilby,r',
#  'Bisang, I': 'bisang,i',
#  'Bishop, LE': 'bishop,le',
#  'Bishop, W': 'bishop,w',
#  'Bisset': 'bisset',
#  'Bittencourt, PV': 'bittencourt,pv',
#  'Bittencourt, SET': 'bittencourt,set',
#  'Bizerril, MX': 'bizerril,mx',
#  'Black': 'black',
#  'Black, CA': 'black,ca',
#  'Black, G': 'black,g',
#  'Black, GA': 'black,ga',
#  'Black, JM': 'black,jm',
#  'Blackmore, J': 'blackmore,j',
#  'Blake, D': 'blake,d',
#  'Blake, ER': 'blake,er',
#  'Blakely, WF': 'blakely,wf',
#  'Blanchet': 'blanchet',
#  'Blanco, S': 'blanco,s',
#  'Blaxell, D': 'blaxell,d',
#  'Block, D': 'block,d',
#  'Blocki': 'blocki',
#  'Blomquist, HL': 'blomquist,hl',
#  'Blotz': 'blotz',
#  'Blum, KE': 'blum,ke',
#  'Boabaid, LF': 'boabaid,lf',
#  'Boaventura, M': 'boaventura,m',
#  'Bocenstain, SS': 'bocenstain,ss',
#  'Bockermann, W': 'bockermann,w',
#  'Bodens, FWP': 'bodens,fwp',
#  'Boeke, J': 'boeke,j',
#  'Boelter, CR': 'boelter,cr',
#  'Boff, SV': 'boff,sv',
#  'Bogner, J': 'bogner,j',
#  'Boguado, MMF': 'boguado,mmf',
#  'Bohlinger, M': 'bohlinger,m',
#  'Bohren, A': 'bohren,a',
#  'Bohrer, P': 'bohrer,p',
#  'Bohs, L': 'bohs,l',
#  'Boiteux, MS': 'boiteux,ms',
#  'Boldingh': 'boldingh',
#  'Boldissera, Z': 'boldissera,z',
#  'Bolten, A': 'bolten,a',
#  'Bolton': 'bolton',
#  'Bomfim, NN': 'bomfim,nn',
#  'Bomley, GL': 'bomley,gl',
#  'Bommer': 'bommer',
#  'Bommer, DFR': 'bommer,dfr',
#  'Bommer, FR': 'bommer,fr',
#  'Bon, Fr HF': 'bon,frhf',
#  'Bonaldo, D': 'bonaldo,d',
#  'Bonasora, MG': 'bonasora,mg',
#  'Bonatto, F': 'bonatto,f',
#  'Bondar, G': 'bondar,g',
#  'Bonilia, M': 'bonilia,m',
#  'Bonniel, G': 'bonniel,g',
#  'Bonomo': 'bonomo',
#  'Bonomo, VS': 'bonomo,vs',
#  'Bonotto, I': 'bonotto,i',
#  'Boom, B': 'boom,b',
#  'Boom, BM': 'boom,bm',
#  'Boone, W': 'boone,w',
#  'Boorman, JL': 'boorman,jl',
#  'Boos, J': 'boos,j',
#  'Boquadi, MMF': 'boquadi,mmf',
#  'Borba, EL': 'borba,el',
#  'Borba, JAF': 'borba,jaf',
#  'Borba, MF': 'borba,mf',
#  'Borborema, PA': 'borborema,pa',
#  'Borchert, MI': 'borchert,mi',
#  'Bordin, J': 'bordin,j',
#  'Bordini, MCP': 'bordini,mcp',
#  'Bordo, A': 'bordo,a',
#  'Borenstaim, SS': 'borenstaim,ss',
#  'Borenstain, SS': 'borenstain,ss',
#  'Borgato, D': 'borgato,d',
#  'Borgato, DF': 'borgato,df',
#  'Borgatto, DF': 'borgatto,df',
#  'Borgerth, A': 'borgerth,a',
#  'Borges, AV': 'borges,av',
#  'Borges, CMO': 'borges,cmo',
#  'Borges, D': 'borges,d',
#  'Borges, DN': 'borges,dn',
#  'Borges, EC': 'borges,ec',
#  'Borges, HBN': 'borges,hbn',
#  'Borges, J': 'borges,j',
#  'Borges, JG': 'borges,jg',
#  'Borges, JW': 'borges,jw',
#  'Borges, JWM': 'borges,jwm',
#  'Borges, KP': 'borges,kp',
#  'Borges, L': 'borges,l',
#  'Borges, LM': 'borges,lm',
#  'Borges, PL': 'borges,pl',
#  'Borges, R': 'borges,r',
#  'Borges, RAX': 'borges,rax',
#  'Borges, RF': 'borges,rf',
#  'Borges, SH': 'borges,sh',
#  'Borges, SM': 'borges,sm',
#  'Borges, SR': 'borges,sr',
#  'Borges, V': 'borges,v',
#  'Borghetti, F': 'borghetti,f',
#  'Borghi, F': 'borghi,f',
#  'Borgo, M': 'borgo,m',
#  'Borin, ALDC': 'borin,aldc',
#  'Boring, LKK': 'boring,lkk',
#  'Born, R': 'born,r',
#  'Borsato, A': 'borsato,a',
#  'Borsini, OH': 'borsini,oh',
#  'Bortoletto, CA': 'bortoletto,ca',
#  'Bortolotto, IM': 'bortolotto,im',
#  'Bortoluzzi, RLC': 'bortoluzzi,rlc',
#  'Bosman, M': 'bosman,m',
#  'Bosquetti, LB': 'bosquetti,lb',
#  'Botelho, MB': 'botelho,mb',
#  'Botinhão, J': 'botinhao,j',
#  'Bouchardet, DA': 'bouchardet,da',
#  'Boudet, HQ': 'boudet,hq',
#  'Bourell, M': 'bourell,m',
#  'Bovey, R': 'bovey,r',
#  'Bovini, M': 'bovini,m',
#  'Bovini, MG': 'bovini,mg',
#  'Boyan, R': 'boyan,r',
#  'Brade': 'brade',
#  'Brade, AC': 'brade,ac',
#  'Braga, A': 'braga,a',
#  'Braga, AGB': 'braga,agb',
#  'Braga, ALV': 'braga,alv',
#  'Braga, EP': 'braga,ep',
#  'Braga, JMA': 'braga,jma',
#  'Braga, JP': 'braga,jp',
#  'Braga, L': 'braga,l',
#  'Braga, MNM': 'braga,mnm',
#  'Braga, P': 'braga,p',
#  'Braga, PIS': 'braga,pis',
#  'Braga, PTS': 'braga,pts',
#  'Braga, R': 'braga,r',
#  'Braga, RDV': 'braga,rdv',
#  'Brahim, KA': 'brahim,ka',
#  'Brako, L': 'brako,l',
#  'Branco, L': 'branco,l',
#  'Branco, R': 'branco,r',
#  'Brand, GD': 'brand,gd',
#  'Brandão, D': 'brandao,d',
#  'Brandão, JLA': 'brandao,jla',
#  'Brandão, L': 'brandao,l',
#  'Brandão, M': 'brandao,m',
#  'Brandão, MMV': 'brandao,mmv',
#  'Brandão, R': 'brandao,r',
#  'Brandão, RA': 'brandao,ra',
#  'Brant, HSC': 'brant,hsc',
#  'Brasileiro, AC': 'brasileiro,ac',
#  'Brasileiro, SS': 'brasileiro,ss',
#  'Brass, LJ': 'brass,lj',
#  'Brasília, EJB': 'brasilia,ejb',
#  'Brasília, TCU': 'brasilia,tcu',
#  'Braun, KP': 'braun,kp',
#  'Braun, S': 'braun,s',
#  'Braz, V': 'braz,v',
#  'Brazão, JEM': 'brazao,jem',
#  'Brazão, U': 'brazao,u',
#  'Breakwell, E': 'breakwell,e',
#  'Bredenkamp, CL': 'bredenkamp,cl',
#  'Breder, J': 'breder,j',
#  'Bredt, A': 'bredt,a',
#  'Breedlove, DE': 'breedlove,de',
#  'Breier, TB': 'breier,tb',
#  'Breitenbach, J': 'breitenbach,j',
#  'Brenan, JPM': 'brenan,jpm',
#  'Brener Roberto': 'brenerroberto',
#  'Brenes, AM': 'brenes,am',
#  'Bresolin': 'bresolin',
#  'Bresolin, A': 'bresolin,a',
#  'Breteler, FJ': 'breteler,fj',
#  'Breteler, FJ14': 'breteler,fj',
#  'Breyer, LM': 'breyer,lm',
#  'Bridgewater, S': 'bridgewater,s',
#  'Brigatto, UA': 'brigatto,ua',
#  'Brighton, CA': 'brighton,ca',
#  'Brilhante, M': 'brilhante,m',
#  'Brinda, J': 'brinda,j',
#  'Bringel, JBA': 'bringel,jba',
#  'Brites, RM': 'brites,rm',
#  'Britez, RM': 'britez,rm',
#  'Brito, AAR': 'brito,aar',
#  'Brito, ACS': 'brito,acs',
#  'Brito, ALTV': 'brito,altv',
#  'Brito, ALVT': 'brito,alvt',
#  'Brito, AT': 'brito,at',
#  'Brito, DS': 'brito,ds',
#  'Brito, ES': 'brito,es',
#  'Brito, HS': 'brito,hs',
#  'Brito, IC': 'brito,ic',
#  'Brito, JAC': 'brito,jac',
#  'Brito, JC': 'brito,jc',
#  'Brito, JM': 'brito,jm',
#  'Brito, KB': 'brito,kb',
#  'Brito, LEB': 'brito,leb',
#  'Brito, M': 'brito,m',
#  'Brito, MCC': 'brito,mcc',
#  'Brito, MH': 'brito,mh',
#  'Brito, P': 'brito,p',
#  'Brito, RM': 'brito,rm',
#  'Brito, SM': 'brito,sm',
#  'Brito, TH': 'brito,th',
#  'Britto, G': 'britto,g',
#  'Britto, IC': 'britto,ic',
#  'Britto, KB': 'britto,kb',
#  'Britto, R': 'britto,r',
#  'Britto, RC': 'britto,rc',
#  'Britton, EG': 'britton,eg',
#  'Britton, NL': 'britton,nl',
#  'Brochado, AL': 'brochado,al',
#  'Brochado, TS': 'brochado,ts',
#  'Brom, ACM': 'brom,acm',
#  'Bromley, G': 'bromley,g',
#  'Bromley, GL': 'bromley,gl',
#  'Brooker, MIH': 'brooker,mih',
#  'Brotherus, VF': 'brotherus,vf',
#  'Brotto, ML': 'brotto,ml',
#  'Brown, FH': 'brown,fh',
#  'Brown, HH': 'brown,hh',
#  'Brown, MT': 'brown,mt',
#  'Browne, GW': 'browne,gw',
#  'Bruera, J': 'bruera,j',
#  'Brugger, M': 'brugger,m',
#  'Brugger, MC': 'brugger,mc',
#  'Bruhl, J': 'bruhl,j',
#  'Brujjer, M': 'brujjer,m',
#  'Brumbach, WC': 'brumbach,wc',
#  'Brummitt, NA': 'brummitt,na',
#  'Bruno': 'bruno',
#  'Brügger, M': 'brugger,m',
#  'Brügger, MC': 'brugger,mc',
#  'Bucci, F': 'bucci,f',
#  'Bucci, FFB': 'bucci,ffb',
#  'Bucher, JP': 'bucher,jp',
#  'Buck, WR': 'buck,wr',
#  'Buddén, I': 'budden,i',
#  'Budziak, C': 'budziak,c',
#  'Bueno': 'bueno',
#  'Bueno, B': 'bueno,b',
#  'Bueno, DF': 'bueno,df',
#  'Bueno, ML': 'bueno,ml',
#  'Bueno, N': 'bueno,n',
#  'Bueno, NC': 'bueno,nc',
#  'Bueno, NRC': 'bueno,nrc',
#  ...}

# %%
remap = {
    #'proenca,c': 'proenca,ceb',
    
    'abreu,lc': 'abreu,lcr',
    'abreu,m': 'abreu,mc',
    'abreu,ms':'abreu,mc',
    'aguiar,ac': 'aguiar,aca',
    'allem,a':'allem,ac',
    
    }

nm.remap(remap)

# %% [markdown]
# ## Names index

# %%
ni = nc.getNamesIndexes(occs, 'recordedBy_atomized',namesMap=nm.getMap())

# %% [markdown]
# ## Assembling the network

# %%
import networkx
import itertools
from collections import Counter

class CoworkingNetwork(networkx.Graph):
    """
    Class for coworking networks. Extends networkx Graph class.
    
    Parameters
    ----------
    namesSets : iterable
        An iterable of iterables containing names used to compose cliques 
        in the network.

    weighted : bool, default False
        If set to True the resulting network will have weighted edges
        
    namesMap : NamesMap
        A NamesMap object for normalizing nodes names.
        
    Examples
    --------
    >>> namesSets = [ ['a','b','c'], ['d','e'], ['a','c'] ]
    >>> CoworkingNetwork( namesSets, weighted=True).edges(data=True)
    [('b', 'a', {'weight': 1}),
     ('b', 'c', {'weight': 1}),
     ('a', 'c', {'weight': 2}),
     ('e', 'd', {'weight': 1})]
    
    >>> CoworkingNetwork( namesSets ).edges(data=True)
    [('b', 'a', {}), 
     ('b', 'c', {}), 
     ('a', 'c', {}), 
     ('e', 'd', {})]
    """
    def __init__(self, namesSets, weighted=False, namesMap=None):
        super().__init__()
        
        if namesMap:
            nmap = namesMap.getMap()
            namesSets = [ [ nmap[n] for n in nset ] for nset in namesSets ]
            
        cliques = map( lambda n: itertools.combinations(n,r=2), namesSets )
        edges = [ e for edges in cliques for e in edges ]
        self.add_edges_from(edges)
        
        if weighted:
            edges_weights = Counter(edges)

            for (u,v),w in edges_weights.items():
                try:
                    self[u][v]['weight'] += w
                except:
                    self[u][v]['weight'] = w
        
        return

# %%
m = nm.getMap()
ni = nc.getNamesIndexes(occs, 'recordedBy_atomized',namesMap=nm.getMap())
G = CoworkingNetwork( occs_collaborative['recordedBy_atomized'], weighted=True, namesMap=nm )
G.remove_node('etal')
nx.write_gexf(G, './graph.gexf')

# %%
nx.set_node_attributes(G, 'n_records', dict( (n, len(ni[n])) for n in G.nodes() ))

# %% [markdown]
# # Next:

# %% [markdown]
# To find potential names variations:
# 1. Find close matches for the names of important nodes;
# 2. For each close match, calculate the similarity of pairs of nodes in terms of their neighbors (cosine similarity?);

# %% [markdown]
# $$sim(n_h, n_l) = \frac{1}{k_l}  \sum_{i=1}^{k_l} g(v_i) , \quad
# g(x) = \begin{cases} 1 \quad x \in S_h \\ 0 \quad x \notin S_h \end{cases}, \qquad \textit{where}$$
#
# * $n_h$ is the higher-degree node;
# * $n_l$ is the lower-degree node;
# * $k_h$ is the degree of node $n_h$;
# * $k_l$ is the degree of node $n_l$;
# * $v_i$ are neighbors of node $n_l$;
# * $S_h$ is the set of neighbors of node $n_h$.

# %%
def neighborhoodSimilarity( G, n1, n2 ):
    if len(G[n1]) > len(G[n2]):
        n_h,n_l = n1,n2
    else:
        n_h,n_l = n2,n1
    
    S = G.neighbors(n_h)
    k_h = G.degree(n_h)
    k_l = G.degree(n_l)
    if k_l > 0:
        return sum( 1 if v in S else 0 for v in G.neighbors(n_l) )/k_l
    else: 
        return 0
    
neighborhoodSimilarity(G, 'proenca,ceb', 'proenca,c')
# Out:
# 0.8260869565217391

# %%
names = [ n for n,d in sorted( G.nodes(data=True), key=lambda x: x[1]['n_records'], reverse=True ) ][:1000]

l=[]
similarity_threshold=0.1
for n1 in names:
    for n2 in [ n2 for n2 in dfl.get_close_matches(n1, names) if n2!=n1 ]:
        sim = neighborhoodSimilarity(G,n1,n2)
        ordered_nodes = sorted([ n1, n2 ])
        if sim >= similarity_threshold:
            l += [ (ordered_nodes[0],ordered_nodes[1],sim) ]
l
# Out:
# [('faria,jeq', 'farias,r', 0.16666666666666666),
#  ('heringer,ep', 'krieger,pl', 0.125),
#  ('concha,c', 'proenca,ceb', 0.6),
#  ('souza,e', 'souza,rr', 0.375),
#  ('souza,mc', 'souza,mgm', 0.14285714285714285),
#  ('eiten,g', 'eiten,lt', 0.7857142857142857),
#  ('zanatta,gv', 'zanatta,mrv', 0.5),
#  ('carvalho,vm', 'carvalhosilva,m', 0.2222222222222222),
#  ('carvalho,', 'carvalhosilva,m', 0.8333333333333334),
#  ('harley,r', 'harley,rm', 0.6),
#  ('fonseca,fs', 'fonseca,s', 1.0),
#  ('kirkbride,mcg', 'kirkbride-junior,jh', 0.2857142857142857),
#  ('eiten,g', 'eiten,lt', 0.7857142857142857),
#  ('pires,jf', 'pires,jn', 1.0),
#  ('gottsberger,g', 'gottsberger,is', 0.6666666666666666),
#  ('hatschbach,g', 'hatschbach,m', 1.0),
#  ('villar,ts', 'villarroel,d', 0.16666666666666666),
#  ('carvalho,avm', 'carvalho,vm', 0.6666666666666666),
#  ('carvalho,avm', 'carvalho,ja', 0.41935483870967744),
#  ('duartesilva,ag', 'soares-silva,lh', 0.125),
#  ('gama,r', 'zampa,l', 1.0),
#  ('ramos,j', 'ramos,jf', 0.14285714285714285),
#  ('martins,cr', 'martins,rc', 0.5),
#  ('fonseca,lm', 'fonseca,ml', 0.26666666666666666),
#  ('gomes,jc', 'gomesjunior,jc', 0.3333333333333333),
#  ('oliveira,rc', 'oliveira,rs', 0.21428571428571427),
#  ('silva,jma', 'silva,ma', 0.25),
#  ('staggemeier,vr', 'staggmeier,vg', 0.6666666666666666),
#  ('grear,jw', 'grearjunior,jw', 0.6),
#  ('chaves,d', 'chaves,da', 0.25),
#  ('ramos,j', 'ramos,pcm', 0.14285714285714285),
#  ('goesjunior,cd', 'silvajunior,mc', 0.5),
#  ('gomes,acm', 'gomes,bm', 0.2857142857142857),
#  ('kuhlmann,m', 'kuhlmann,mp', 0.3333333333333333),
#  ('carvalho,ps', 'carvalho,sf', 0.3333333333333333),
#  ('reis,gr', 'reis,pa', 0.16666666666666666),
#  ('freitas,rip', 'reis,pa', 0.2),
#  ('oliveira,fcao', 'oliveira,vc', 0.6666666666666666),
#  ('fonseca,j', 'fonsecafilho,j', 0.6071428571428571),
#  ('silva,mn', 'silva,nt', 0.125),
#  ('lima,j', 'lima,jcm', 0.3),
#  ('souza,enf', 'souza,lf', 0.1111111111111111),
#  ('kirkbride,mcg', 'kirkbride-junior,jh', 0.2857142857142857),
#  ('martins,cr', 'martins,rc', 0.5),
#  ('sampaio,ab', 'scariot,ao', 0.1111111111111111),
#  ('pinheiro,r', 'pinheiro,rs', 0.25),
#  ('moreira,h', 'moreira,hjc', 0.5),
#  ('fagg,cw', 'fagg,jmf', 0.8571428571428571),
#  ('duarte,ap', 'duarte,ar', 0.25),
#  ('cardoso,de', 'cardoso,es', 0.16666666666666666),
#  ('silva,ss', 'souzasilva,s', 0.8333333333333334),
#  ('mecenas,vv', 'mendes,vc', 0.2692307692307692),
#  ('king,lrm', 'king,rm', 0.6666666666666666),
#  ('silva,lv', 'silvestre,lfv', 0.16666666666666666),
#  ('ramos,ae', 'ramos,j', 0.21052631578947367),
#  ('ramos,ae', 'ramos,jf', 0.10526315789473684),
#  ('filgueiras,ad', 'filgueiras,ts', 0.75),
#  ('alvarenga,a', 'alvarenga,d', 0.8),
#  ('oliveira,rir', 'oliveira,rs', 0.25),
#  ('duartesilva,ag', 'silva,agd', 0.875),
#  ('queiroz,lp', 'queiroz,rf', 0.25),
#  ('turmadeetnobotanicadocerrado', 'turmadevegetacaodocerrado', 0.5),
#  ('turmadebotanicadecampo', 'turmadevegetacaodocerrado', 0.1111111111111111),
#  ('moreira,ph', 'moreira,tb', 0.5),
#  ('chaves,d', 'chaves,e', 0.25),
#  ('mimura,i', 'miranda,is', 1.0),
#  ('ianhez,m', 'ianhez,ml', 0.3333333333333333),
#  ('barros,m', 'barros,mag', 0.5),
#  ('ribeiro,jf', 'ribeiro,mf', 0.14285714285714285),
#  ('kuhlmann,m', 'kuhlmann,mp', 0.3333333333333333),
#  ('amorim,a', 'amorim,eh', 0.13333333333333333),
#  ('silva,ap', 'silva,pe', 0.3333333333333333),
#  ('silva,ap', 'silva,ma', 0.3157894736842105),
#  ('staggemeier,vr', 'staggmeier,vg', 0.6666666666666666),
#  ('turmadebotanicadecampo', 'turmadeetnobotanicadocerrado', 0.5),
#  ('junqueira,di', 'siqueira,gs', 0.1),
#  ('macedo,a', 'macedo,m', 1.0),
#  ('gottsberger,g', 'gottsberger,is', 0.6666666666666666),
#  ('cardoso,de', 'cardoso,es', 0.16666666666666666),
#  ('reis,gr', 'reis,pa', 0.16666666666666666),
#  ('souza,jp', 'souza,vc', 0.8260869565217391),
#  ('almeida,sms', 'almeida,sp', 1.0),
#  ('silva,mn', 'silva,n', 0.5),
#  ('bezerra,kmg', 'gomesbezerra,km', 0.4),
#  ('krieger,l', 'krieger,pl', 0.25),
#  ('reisjunior,fb', 'simpson-junior,pl', 0.3333333333333333),
#  ('maguire,b', 'maguire,ck', 0.9),
#  ('leite,fq', 'leite,lq', 1.0),
#  ('souza,acm', 'souza,vc', 0.125),
#  ('oliveira,de', 'oliveira,dr', 0.5),
#  ('silva,jma', 'silva,ma', 0.25),
#  ('barbosa,e', 'barboza,e', 0.38461538461538464),
#  ('cordeiro,i', 'cordeiro,j', 0.1),
#  ('rodrigues,as', 'rodrigues,n', 0.1),
#  ('landim,mf', 'landrum,l', 0.375),
#  ('silva,jc', 'silva,jcs', 0.5625),
#  ('moura,co', 'moura,io', 0.125),
#  ('krieger,l', 'krieger,pl', 0.25),
#  ('heringer,ep', 'krieger,pl', 0.125),
#  ('pott,a', 'pott,vj', 0.5),
#  ('cordeiro,i', 'cordeiro,j', 0.1),
#  ('carvalho,vm', 'fankdecarvalho,sm', 0.2222222222222222),
#  ('carvalho,sf', 'fankdecarvalho,sm', 1.0),
#  ('lima,a', 'lima,n', 0.5),
#  ('brito,hs', 'brito,m', 0.3333333333333333),
#  ('silva,pe', 'silva,pen', 0.6666666666666666),
#  ('lorenco,jlm', 'lourenco,jlm', 0.16666666666666666),
#  ('lourenco,jlm', 'lourenco,jml', 0.3333333333333333),
#  ('farias,r', 'freitas,rip', 0.4),
#  ('santos,gb', 'santos,jb', 0.4444444444444444),
#  ('ianhez,m', 'ianhez,ml', 0.3333333333333333),
#  ('bonasora,mg', 'nobrega,mg', 0.25),
#  ('arantes,aa', 'versiane,afa', 0.18181818181818182),
#  ('nascimento,ea', 'nascimento,tr', 0.2),
#  ('mattos,j', 'mattos,jr', 0.25),
#  ('rodrig', 'rodrigues,n', 0.42857142857142855),
#  ('hatschbach,g', 'hatschbach,m', 1.0),
#  ('moretto,gl', 'noletto,lg', 0.5),
#  ('mori,s', 'mori,sa', 0.5555555555555556),
#  ('laine,k', 'laine,u', 0.3333333333333333),
#  ('silva,ja', 'silva,ma', 0.125),
#  ('santana,s', 'santana,sc', 0.5666666666666667),
#  ('amorim,eh', 'hattori,eko', 0.4666666666666667),
#  ('oliveira,nro', 'oliveira,o', 0.5),
#  ('oliveira,nro', 'oliveira,rs', 0.21428571428571427),
#  ('moretto,gl', 'noletto,lg', 0.5),
#  ('mores,jlg', 'moretto,gl', 0.5),
#  ('giulietti,am', 'giulietti,aml', 0.5),
#  ('giulietti,aml', 'giulietti,n', 0.26666666666666666),
#  ('cordeiro,i', 'cornelio,in', 0.14285714285714285),
#  ('santos,e', 'santos,eb', 0.13333333333333333),
#  ('freitas,gs', 'reis,gr', 0.25),
#  ('franca,f', 'furlan,a', 0.10344827586206896),
#  ('brito,hs', 'brito,m', 0.3333333333333333),
#  ('lorenco,jlm', 'lourenco,jlm', 0.16666666666666666),
#  ('lorenco,jlm', 'lourenco,jml', 0.6666666666666666),
#  ('bonomo', 'bonomo,vs', 0.5),
#  ('damasceno,ga', 'damascenojunior,ga', 0.45454545454545453),
#  ('ramos,j', 'ramos,jf', 0.14285714285714285),
#  ('leite,fq', 'leite,lq', 1.0),
#  ('landrum,l', 'landrum,lr', 0.625),
#  ('landrum,l', 'landrum,ss', 0.16666666666666666),
#  ('pinheiro,r', 'pinheiro,rs', 0.25),
#  ('almeida,sms', 'almeida,sp', 1.0),
#  ('mattos,j', 'mattos,jr', 0.25),
#  ('mattos,a', 'mattos,jr', 0.5),
#  ('barros,m', 'barros,mls', 0.2),
#  ('cobra,l', 'cobra,lq', 0.5),
#  ('fonseca,j', 'fonseca,js', 0.5),
#  ('fonseca,j', 'fonseca,s', 0.25),
#  ('arantes,aa', 'versiane,afa', 0.18181818181818182),
#  ('silva,bm', 'silva,rm', 0.10344827586206896),
#  ('batista,ac', 'batista,jan', 0.14285714285714285),
#  ('campos,jmp', 'campos,sm', 1.0),
#  ('king,lrm', 'king,rm', 0.6666666666666666),
#  ('amorim,a', 'amorim,am', 0.4838709677419355),
#  ('barbosa,e', 'barboza,e', 0.38461538461538464),
#  ('duarte,ap', 'duarte,ar', 0.25),
#  ('moreira,h', 'moreira,hjc', 0.5),
#  ('rocha,m', 'rocha,mp', 0.3333333333333333),
#  ('barros,m', 'barros,mls', 0.2),
#  ('landrum,l', 'landrum,ss', 0.16666666666666666),
#  ('landrum,lr', 'landrum,ss', 0.6666666666666666),
#  ('lima,j', 'lima,jcm', 0.3),
#  ('santos,e', 'santos,eb', 0.13333333333333333),
#  ('santos,eb', 'santos,jb', 0.13333333333333333),
#  ('fonseca,j', 'fonseca,js', 0.5),
#  ('brochado,al', 'rocha,m', 0.14285714285714285),
#  ('parente,hm', 'pereiraneto,m', 0.3333333333333333),
#  ('grear,jw', 'grearjunior,jw', 0.6),
#  ('cobra,l', 'cobra,lq', 0.5),
#  ('silva,jc', 'silva,jcs', 0.5625),
#  ('giulietti,am', 'giulietti,n', 0.6),
#  ('giulietti,aml', 'giulietti,n', 0.26666666666666666),
#  ('sanaiotti,tm', 'sano,sm', 0.14285714285714285),
#  ('nascimento,ea', 'nascimento,tr', 0.2),
#  ('maguire,b', 'maguire,ck', 0.9),
#  ('bonomo', 'bonomo,vs', 0.5),
#  ('lima,es', 'lima,hs', 0.25),
#  ('santos,ml', 'sato,mn', 0.3333333333333333),
#  ('chaves,d', 'chaves,da', 0.25),
#  ('chaves,d', 'chaves,e', 0.25),
#  ('pott,a', 'pott,vj', 0.5),
#  ('turmadeetnobotanicadocerrado', 'turmadevegetacaodocerrado', 0.5),
#  ('turmadebotanicadecampo', 'turmadeetnobotanicadocerrado', 0.5),
#  ('campos,jmp', 'campos,sm', 1.0),
#  ('santana,me', 'santanna,me', 0.6666666666666666),
#  ('carvalho,ps', 'carvalho,sf', 0.3333333333333333),
#  ('occhioni,p', 'schinini,a', 0.5),
#  ('silva,ml', 'silva,rm', 0.1111111111111111),
#  ('silva,mn', 'silva,n', 0.5),
#  ('klein,r', 'klein,rm', 0.6666666666666666),
#  ('klein', 'klein,r', 0.4),
#  ('klein,r', 'klein,rm', 0.6666666666666666),
#  ('pires,jf', 'pires,jn', 1.0),
#  ('damasceno,ga', 'damascenojunior,ga', 0.45454545454545453),
#  ('harley,r', 'harley,rm', 0.6),
#  ('santana,s', 'santana,sh', 0.23076923076923078),
#  ('santana,s', 'santana,sc', 0.5666666666666667),
#  ('batista,ac', 'batista,jan', 0.14285714285714285),
#  ('alvarenga,a', 'alvarenga,d', 0.8),
#  ('santana,s', 'santana,sh', 0.23076923076923078),
#  ('giulietti,am', 'giulietti,aml', 0.5),
#  ('giulietti,am', 'giulietti,n', 0.6),
#  ('amorim,a', 'amorim,am', 0.4838709677419355),
#  ('amorim,a', 'amorim,eh', 0.13333333333333333),
#  ('zanatta,gv', 'zanatta,mrv', 0.5),
#  ('macedo,a', 'macedo,m', 1.0),
#  ('fonseca,fs', 'fonseca,s', 1.0),
#  ('clemente,cm', 'mendes,vc', 0.25),
#  ('laine,k', 'laine,u', 0.3333333333333333),
#  ('santana,me', 'santanna,me', 0.6666666666666666),
#  ('santana,s', 'santanna,me', 0.25),
#  ('queiroz,lp', 'queiroz,rf', 0.25),
#  ('lourenco,jlm', 'lourenco,jml', 0.3333333333333333),
#  ('lorenco,jlm', 'lourenco,jml', 0.6666666666666666),
#  ('bean,mf', 'libano,am', 0.3333333333333333),
#  ('bean,mf', 'landim,mf', 0.6666666666666666),
#  ('dias,ace', 'dias,ar', 0.3333333333333333),
#  ('fonseca,lm', 'fonseca,ml', 0.26666666666666666),
#  ('filgueiras,ad', 'filgueiras,ts', 0.75),
#  ('gracianoribeiro,d', 'ribeiro,dg', 0.6),
#  ('borgato,d', 'borgatto,df', 0.75),
#  ('maia,wd', 'maria,j', 0.5),
#  ('fagg,cw', 'fagg,jmf', 0.8571428571428571),
#  ('rocha,m', 'rocha,mp', 0.3333333333333333),
#  ('ribeiro,jf', 'ribeiro,mf', 0.14285714285714285),
#  ('carvalho,avm', 'carvalho,vm', 0.6666666666666666),
#  ('oliveira,nro', 'oliveira,o', 0.5),
#  ('sevilha,ac', 'silva,ma', 0.5),
#  ('villar,ts', 'villarroel,d', 0.16666666666666666),
#  ('otoni,t', 'soto,d', 0.25),
#  ('gama,r', 'zampa,l', 1.0),
#  ('salviani,er', 'silva,sr', 0.16666666666666666),
#  ('souza,fc', 'souza,mc', 0.25),
#  ('bezerra,kmg', 'gomesbezerra,km', 0.4),
#  ('gomes,sm', 'gomesbezerra,km', 0.2),
#  ('harley,rm', 'wanderley,mgl', 0.125),
#  ('silva,pe', 'silva,pen', 0.6666666666666666),
#  ('bresolin', 'bresolin,a', 0.75),
#  ('moura,co', 'moura,io', 0.125),
#  ('figueiredo,rr', 'filgueiras,ts', 0.2),
#  ('landrum,l', 'landrum,lr', 0.625),
#  ('landrum,lr', 'landrum,ss', 0.6666666666666666),
#  ('borgato,d', 'borgatto,df', 0.75),
#  ('davidse,g', 'davis,ew', 0.16666666666666666),
#  ('mori,s', 'mori,sa', 0.5555555555555556),
#  ('bresolin', 'bresolin,a', 0.75),
#  ('occhioni,p', 'schinini,a', 0.5),
#  ('ferreira,a', 'ferreira,hd', 0.14285714285714285),
#  ('klein', 'klein,r', 0.4),
#  ('klein', 'klein,rm', 0.8)]

# %%
sorted(l, key=lambda x: x[2],reverse=True)
# Out:
# [('fonseca,fs', 'fonseca,s', 1.0),
#  ('pires,jf', 'pires,jn', 1.0),
#  ('hatschbach,g', 'hatschbach,m', 1.0),
#  ('gama,r', 'zampa,l', 1.0),
#  ('mimura,i', 'miranda,is', 1.0),
#  ('macedo,a', 'macedo,m', 1.0),
#  ('almeida,sms', 'almeida,sp', 1.0),
#  ('leite,fq', 'leite,lq', 1.0),
#  ('carvalho,sf', 'fankdecarvalho,sm', 1.0),
#  ('hatschbach,g', 'hatschbach,m', 1.0),
#  ('leite,fq', 'leite,lq', 1.0),
#  ('almeida,sms', 'almeida,sp', 1.0),
#  ('campos,jmp', 'campos,sm', 1.0),
#  ('campos,jmp', 'campos,sm', 1.0),
#  ('pires,jf', 'pires,jn', 1.0),
#  ('macedo,a', 'macedo,m', 1.0),
#  ('fonseca,fs', 'fonseca,s', 1.0),
#  ('gama,r', 'zampa,l', 1.0),
#  ('maguire,b', 'maguire,ck', 0.9),
#  ('maguire,b', 'maguire,ck', 0.9),
#  ('duartesilva,ag', 'silva,agd', 0.875),
#  ('fagg,cw', 'fagg,jmf', 0.8571428571428571),
#  ('fagg,cw', 'fagg,jmf', 0.8571428571428571),
#  ('carvalho,', 'carvalhosilva,m', 0.8333333333333334),
#  ('silva,ss', 'souzasilva,s', 0.8333333333333334),
#  ('souza,jp', 'souza,vc', 0.8260869565217391),
#  ('alvarenga,a', 'alvarenga,d', 0.8),
#  ('alvarenga,a', 'alvarenga,d', 0.8),
#  ('klein', 'klein,rm', 0.8),
#  ('eiten,g', 'eiten,lt', 0.7857142857142857),
#  ('eiten,g', 'eiten,lt', 0.7857142857142857),
#  ('filgueiras,ad', 'filgueiras,ts', 0.75),
#  ('filgueiras,ad', 'filgueiras,ts', 0.75),
#  ('borgato,d', 'borgatto,df', 0.75),
#  ('bresolin', 'bresolin,a', 0.75),
#  ('borgato,d', 'borgatto,df', 0.75),
#  ('bresolin', 'bresolin,a', 0.75),
#  ('gottsberger,g', 'gottsberger,is', 0.6666666666666666),
#  ('carvalho,avm', 'carvalho,vm', 0.6666666666666666),
#  ('staggemeier,vr', 'staggmeier,vg', 0.6666666666666666),
#  ('oliveira,fcao', 'oliveira,vc', 0.6666666666666666),
#  ('king,lrm', 'king,rm', 0.6666666666666666),
#  ('staggemeier,vr', 'staggmeier,vg', 0.6666666666666666),
#  ('gottsberger,g', 'gottsberger,is', 0.6666666666666666),
#  ('silva,pe', 'silva,pen', 0.6666666666666666),
#  ('lorenco,jlm', 'lourenco,jml', 0.6666666666666666),
#  ('king,lrm', 'king,rm', 0.6666666666666666),
#  ('landrum,lr', 'landrum,ss', 0.6666666666666666),
#  ('santana,me', 'santanna,me', 0.6666666666666666),
#  ('klein,r', 'klein,rm', 0.6666666666666666),
#  ('klein,r', 'klein,rm', 0.6666666666666666),
#  ('santana,me', 'santanna,me', 0.6666666666666666),
#  ('lorenco,jlm', 'lourenco,jml', 0.6666666666666666),
#  ('bean,mf', 'landim,mf', 0.6666666666666666),
#  ('carvalho,avm', 'carvalho,vm', 0.6666666666666666),
#  ('silva,pe', 'silva,pen', 0.6666666666666666),
#  ('landrum,lr', 'landrum,ss', 0.6666666666666666),
#  ('landrum,l', 'landrum,lr', 0.625),
#  ('landrum,l', 'landrum,lr', 0.625),
#  ('fonseca,j', 'fonsecafilho,j', 0.6071428571428571),
#  ('concha,c', 'proenca,ceb', 0.6),
#  ('harley,r', 'harley,rm', 0.6),
#  ('grear,jw', 'grearjunior,jw', 0.6),
#  ('grear,jw', 'grearjunior,jw', 0.6),
#  ('giulietti,am', 'giulietti,n', 0.6),
#  ('harley,r', 'harley,rm', 0.6),
#  ('giulietti,am', 'giulietti,n', 0.6),
#  ('gracianoribeiro,d', 'ribeiro,dg', 0.6),
#  ('santana,s', 'santana,sc', 0.5666666666666667),
#  ('santana,s', 'santana,sc', 0.5666666666666667),
#  ('silva,jc', 'silva,jcs', 0.5625),
#  ('silva,jc', 'silva,jcs', 0.5625),
#  ('mori,s', 'mori,sa', 0.5555555555555556),
#  ('mori,s', 'mori,sa', 0.5555555555555556),
#  ('zanatta,gv', 'zanatta,mrv', 0.5),
#  ('martins,cr', 'martins,rc', 0.5),
#  ('goesjunior,cd', 'silvajunior,mc', 0.5),
#  ('martins,cr', 'martins,rc', 0.5),
#  ('moreira,h', 'moreira,hjc', 0.5),
#  ('turmadeetnobotanicadocerrado', 'turmadevegetacaodocerrado', 0.5),
#  ('moreira,ph', 'moreira,tb', 0.5),
#  ('barros,m', 'barros,mag', 0.5),
#  ('turmadebotanicadecampo', 'turmadeetnobotanicadocerrado', 0.5),
#  ('silva,mn', 'silva,n', 0.5),
#  ('oliveira,de', 'oliveira,dr', 0.5),
#  ('pott,a', 'pott,vj', 0.5),
#  ('lima,a', 'lima,n', 0.5),
#  ('moretto,gl', 'noletto,lg', 0.5),
#  ('oliveira,nro', 'oliveira,o', 0.5),
#  ('moretto,gl', 'noletto,lg', 0.5),
#  ('mores,jlg', 'moretto,gl', 0.5),
#  ('giulietti,am', 'giulietti,aml', 0.5),
#  ('bonomo', 'bonomo,vs', 0.5),
#  ('mattos,a', 'mattos,jr', 0.5),
#  ('cobra,l', 'cobra,lq', 0.5),
#  ('fonseca,j', 'fonseca,js', 0.5),
#  ('moreira,h', 'moreira,hjc', 0.5),
#  ('fonseca,j', 'fonseca,js', 0.5),
#  ('cobra,l', 'cobra,lq', 0.5),
#  ('bonomo', 'bonomo,vs', 0.5),
#  ('pott,a', 'pott,vj', 0.5),
#  ('turmadeetnobotanicadocerrado', 'turmadevegetacaodocerrado', 0.5),
#  ('turmadebotanicadecampo', 'turmadeetnobotanicadocerrado', 0.5),
#  ('occhioni,p', 'schinini,a', 0.5),
#  ('silva,mn', 'silva,n', 0.5),
#  ('giulietti,am', 'giulietti,aml', 0.5),
#  ('zanatta,gv', 'zanatta,mrv', 0.5),
#  ('maia,wd', 'maria,j', 0.5),
#  ('oliveira,nro', 'oliveira,o', 0.5),
#  ('sevilha,ac', 'silva,ma', 0.5),
#  ('occhioni,p', 'schinini,a', 0.5),
#  ('amorim,a', 'amorim,am', 0.4838709677419355),
#  ('amorim,a', 'amorim,am', 0.4838709677419355),
#  ('amorim,eh', 'hattori,eko', 0.4666666666666667),
#  ('damasceno,ga', 'damascenojunior,ga', 0.45454545454545453),
#  ('damasceno,ga', 'damascenojunior,ga', 0.45454545454545453),
#  ('santos,gb', 'santos,jb', 0.4444444444444444),
#  ('rodrig', 'rodrigues,n', 0.42857142857142855),
#  ('carvalho,avm', 'carvalho,ja', 0.41935483870967744),
#  ('bezerra,kmg', 'gomesbezerra,km', 0.4),
#  ('farias,r', 'freitas,rip', 0.4),
#  ('klein', 'klein,r', 0.4),
#  ('bezerra,kmg', 'gomesbezerra,km', 0.4),
#  ('klein', 'klein,r', 0.4),
#  ('barbosa,e', 'barboza,e', 0.38461538461538464),
#  ('barbosa,e', 'barboza,e', 0.38461538461538464),
#  ('souza,e', 'souza,rr', 0.375),
#  ('landim,mf', 'landrum,l', 0.375),
#  ('gomes,jc', 'gomesjunior,jc', 0.3333333333333333),
#  ('kuhlmann,m', 'kuhlmann,mp', 0.3333333333333333),
#  ('carvalho,ps', 'carvalho,sf', 0.3333333333333333),
#  ('ianhez,m', 'ianhez,ml', 0.3333333333333333),
#  ('kuhlmann,m', 'kuhlmann,mp', 0.3333333333333333),
#  ('silva,ap', 'silva,pe', 0.3333333333333333),
#  ('reisjunior,fb', 'simpson-junior,pl', 0.3333333333333333),
#  ('brito,hs', 'brito,m', 0.3333333333333333),
#  ('lourenco,jlm', 'lourenco,jml', 0.3333333333333333),
#  ('ianhez,m', 'ianhez,ml', 0.3333333333333333),
#  ('laine,k', 'laine,u', 0.3333333333333333),
#  ('brito,hs', 'brito,m', 0.3333333333333333),
#  ('rocha,m', 'rocha,mp', 0.3333333333333333),
#  ('parente,hm', 'pereiraneto,m', 0.3333333333333333),
#  ('santos,ml', 'sato,mn', 0.3333333333333333),
#  ('carvalho,ps', 'carvalho,sf', 0.3333333333333333),
#  ('laine,k', 'laine,u', 0.3333333333333333),
#  ('lourenco,jlm', 'lourenco,jml', 0.3333333333333333),
#  ('bean,mf', 'libano,am', 0.3333333333333333),
#  ('dias,ace', 'dias,ar', 0.3333333333333333),
#  ('rocha,m', 'rocha,mp', 0.3333333333333333),
#  ('silva,ap', 'silva,ma', 0.3157894736842105),
#  ('lima,j', 'lima,jcm', 0.3),
#  ('lima,j', 'lima,jcm', 0.3),
#  ('kirkbride,mcg', 'kirkbride-junior,jh', 0.2857142857142857),
#  ('gomes,acm', 'gomes,bm', 0.2857142857142857),
#  ('kirkbride,mcg', 'kirkbride-junior,jh', 0.2857142857142857),
#  ('mecenas,vv', 'mendes,vc', 0.2692307692307692),
#  ('fonseca,lm', 'fonseca,ml', 0.26666666666666666),
#  ('giulietti,aml', 'giulietti,n', 0.26666666666666666),
#  ('giulietti,aml', 'giulietti,n', 0.26666666666666666),
#  ('fonseca,lm', 'fonseca,ml', 0.26666666666666666),
#  ('silva,jma', 'silva,ma', 0.25),
#  ('chaves,d', 'chaves,da', 0.25),
#  ('pinheiro,r', 'pinheiro,rs', 0.25),
#  ('duarte,ap', 'duarte,ar', 0.25),
#  ('oliveira,rir', 'oliveira,rs', 0.25),
#  ('queiroz,lp', 'queiroz,rf', 0.25),
#  ('chaves,d', 'chaves,e', 0.25),
#  ('krieger,l', 'krieger,pl', 0.25),
#  ('silva,jma', 'silva,ma', 0.25),
#  ('krieger,l', 'krieger,pl', 0.25),
#  ('bonasora,mg', 'nobrega,mg', 0.25),
#  ('mattos,j', 'mattos,jr', 0.25),
#  ('freitas,gs', 'reis,gr', 0.25),
#  ('pinheiro,r', 'pinheiro,rs', 0.25),
#  ('mattos,j', 'mattos,jr', 0.25),
#  ('fonseca,j', 'fonseca,s', 0.25),
#  ('duarte,ap', 'duarte,ar', 0.25),
#  ('lima,es', 'lima,hs', 0.25),
#  ('chaves,d', 'chaves,da', 0.25),
#  ('chaves,d', 'chaves,e', 0.25),
#  ('clemente,cm', 'mendes,vc', 0.25),
#  ('santana,s', 'santanna,me', 0.25),
#  ('queiroz,lp', 'queiroz,rf', 0.25),
#  ('otoni,t', 'soto,d', 0.25),
#  ('souza,fc', 'souza,mc', 0.25),
#  ('santana,s', 'santana,sh', 0.23076923076923078),
#  ('santana,s', 'santana,sh', 0.23076923076923078),
#  ('carvalho,vm', 'carvalhosilva,m', 0.2222222222222222),
#  ('carvalho,vm', 'fankdecarvalho,sm', 0.2222222222222222),
#  ('oliveira,rc', 'oliveira,rs', 0.21428571428571427),
#  ('oliveira,nro', 'oliveira,rs', 0.21428571428571427),
#  ('ramos,ae', 'ramos,j', 0.21052631578947367),
#  ('freitas,rip', 'reis,pa', 0.2),
#  ('nascimento,ea', 'nascimento,tr', 0.2),
#  ('barros,m', 'barros,mls', 0.2),
#  ('barros,m', 'barros,mls', 0.2),
#  ('nascimento,ea', 'nascimento,tr', 0.2),
#  ('gomes,sm', 'gomesbezerra,km', 0.2),
#  ('figueiredo,rr', 'filgueiras,ts', 0.2),
#  ('arantes,aa', 'versiane,afa', 0.18181818181818182),
#  ('arantes,aa', 'versiane,afa', 0.18181818181818182),
#  ('faria,jeq', 'farias,r', 0.16666666666666666),
#  ('villar,ts', 'villarroel,d', 0.16666666666666666),
#  ('reis,gr', 'reis,pa', 0.16666666666666666),
#  ('cardoso,de', 'cardoso,es', 0.16666666666666666),
#  ('silva,lv', 'silvestre,lfv', 0.16666666666666666),
#  ('cardoso,de', 'cardoso,es', 0.16666666666666666),
#  ('reis,gr', 'reis,pa', 0.16666666666666666),
#  ('lorenco,jlm', 'lourenco,jlm', 0.16666666666666666),
#  ('lorenco,jlm', 'lourenco,jlm', 0.16666666666666666),
#  ('landrum,l', 'landrum,ss', 0.16666666666666666),
#  ('landrum,l', 'landrum,ss', 0.16666666666666666),
#  ('villar,ts', 'villarroel,d', 0.16666666666666666),
#  ('salviani,er', 'silva,sr', 0.16666666666666666),
#  ('davidse,g', 'davis,ew', 0.16666666666666666),
#  ('souza,mc', 'souza,mgm', 0.14285714285714285),
#  ('ramos,j', 'ramos,jf', 0.14285714285714285),
#  ('ramos,j', 'ramos,pcm', 0.14285714285714285),
#  ('ribeiro,jf', 'ribeiro,mf', 0.14285714285714285),
#  ('cordeiro,i', 'cornelio,in', 0.14285714285714285),
#  ('ramos,j', 'ramos,jf', 0.14285714285714285),
#  ('batista,ac', 'batista,jan', 0.14285714285714285),
#  ('brochado,al', 'rocha,m', 0.14285714285714285),
#  ('sanaiotti,tm', 'sano,sm', 0.14285714285714285),
#  ('batista,ac', 'batista,jan', 0.14285714285714285),
#  ('ribeiro,jf', 'ribeiro,mf', 0.14285714285714285),
#  ('ferreira,a', 'ferreira,hd', 0.14285714285714285),
#  ('amorim,a', 'amorim,eh', 0.13333333333333333),
#  ('santos,e', 'santos,eb', 0.13333333333333333),
#  ('santos,e', 'santos,eb', 0.13333333333333333),
#  ('santos,eb', 'santos,jb', 0.13333333333333333),
#  ('amorim,a', 'amorim,eh', 0.13333333333333333),
#  ('heringer,ep', 'krieger,pl', 0.125),
#  ('duartesilva,ag', 'soares-silva,lh', 0.125),
#  ('silva,mn', 'silva,nt', 0.125),
#  ('souza,acm', 'souza,vc', 0.125),
#  ('moura,co', 'moura,io', 0.125),
#  ('heringer,ep', 'krieger,pl', 0.125),
#  ('silva,ja', 'silva,ma', 0.125),
#  ('harley,rm', 'wanderley,mgl', 0.125),
#  ('moura,co', 'moura,io', 0.125),
#  ('souza,enf', 'souza,lf', 0.1111111111111111),
#  ('sampaio,ab', 'scariot,ao', 0.1111111111111111),
#  ('turmadebotanicadecampo', 'turmadevegetacaodocerrado', 0.1111111111111111),
#  ('silva,ml', 'silva,rm', 0.1111111111111111),
#  ('ramos,ae', 'ramos,jf', 0.10526315789473684),
#  ('franca,f', 'furlan,a', 0.10344827586206896),
#  ('silva,bm', 'silva,rm', 0.10344827586206896),
#  ('junqueira,di', 'siqueira,gs', 0.1),
#  ('cordeiro,i', 'cordeiro,j', 0.1),
#  ('rodrigues,as', 'rodrigues,n', 0.1),
#  ('cordeiro,i', 'cordeiro,j', 0.1)]

# %%
G['barbosa,e']
# Out:
# {'abe,lm': {'weight': 10},
#  'cervi,ca': {'weight': 3},
#  'cordeiro,e': {'weight': 1},
#  'cordeiro,i': {'weight': 1},
#  'cordeiro,j': {'weight': 24},
#  'costa,ef': {'weight': 8},
#  'cruz,jm': {'weight': 8},
#  'fagundes,ja': {'weight': 3},
#  'ferreira,la': {'weight': 6},
#  'goldenberg,r': {'weight': 2},
#  'hatschbach,g': {'weight': 57},
#  'hatschbach,m': {'weight': 37},
#  'mansano,vs': {'weight': 1},
#  'pereira,lbs': {'weight': 1},
#  'poliquesi,cb': {'weight': 11},
#  'pott,a': {'weight': 3},
#  'pott,v': {'weight': 3},
#  'ribas,os': {'weight': 14},
#  'schinini,a': {'weight': 1},
#  'silva,jm': {'weight': 43},
#  'silva,lbp': {'weight': 1},
#  'spichiger,r': {'weight': 1},
#  'vaz,s': {'weight': 1}}

# %%
occs.loc[ni['munhoz,ca']]
# Out:
#        collectionCode                                         recordedBy  \
# 4344               UB  Barros, MAG; Filgueiras, TS; Silva, PEN; Munho...
# 113553             UB  Barros, M; Filgueiras, TS; Munhoz, CA; Nascime...
#
#                            scientificName taxonRank  \
# 4344    Prescottia oligantha (Sw.) Lindl.   SPECIES
# 113553   Byrsonima verbascifolia (L.) DC.   SPECIES
#
#                                       recordedBy_atomized
# 4344    [Barros, MAG, Filgueiras, TS, Silva, PEN, Munh...
# 113553  [Barros, M, Filgueiras, TS, Munhoz, CA, Nascim...

# %%
remap = {
    'gawryszewski,fm': 'grawryszewski,fm',
    'coradin,l': 'coradin,lc',
    'jennings,': 'jennings,lvs',
    'kolmann,l': 'kollmann,l',
    'vera,l': 'veralucia',
    'clemente,c': 'clemente,cm',
    'bertolda,j': 'bertoldo,j',
    'smith,g': 'smith,gl',
    'vaz,a': 'vaz,amsf',
    'sena,l': 'senna,l',
    'sanaiotti,t': 'sanaiotti,tm',
    'klein,vl': 'klein,vlg',
    'casto,ws': 'castro,ws',
    'dias,ej': 'dias,jb',
    'torres,dc': 'torres,dsc',
    'landim,m': 'landim,mf',
    'silva,lh': 'soares-silva,lh', 
    'soaressilva,lh': 'soares-silva,lh',
    'silva,lhs': 'soares-silva,lh',
    'oliveira,ma': 'oliveira,ms',
    'borges,r': 'borges,rax',
    'oliveira,s': 'oliveira,scc',
    'lage,jl': 'hage,jl',
    'maas,h': 'maas,pjm',
    'cardoso,e': 'cardoso,es',
    'proenca,c': 'proenca,ceb',
    'noleto,l': 'noletto,lg',
    'rudall,p': 'ruddall,p',
    'chiea,sac': 'chiea,sc',
    'cielofilho,r':'cielo-filho,r', 
    'filho,rc':'cielo-filho,r',
    'cid,ca': 'cid,cac',
    'nascimento,e': 'nascimento,ea',f
    'jardim,j': 'jardim,jg',
    'villaroel,d': 'villarroel,d',
    'wagner': 'wagner,hl',
    'dias,bj': 'dias,jb',
    'amorim,p': 'amorim,pr',
    'flores': 'flores,tb',
    'lucas,e': 'lucas,ej',
    'morbeck': 'morbeck,a',
    'castro,r': 'castro,ra',
    'passon,l': 'passon,lm',
    'simpson,pl': 'simpson-junior,pl', 
    'simpsonjunior,pl': 'simpson-junior,pl',
    'paulasouza,j': 'souza,jp',
    'coveny,r': 'coveny,rg',
    'crosby': 'crosby,mr',
    'souza,cv': 'souza,vc',
    'moreira,al': 'moreira,alc',
    'nobs,ma': 'noles,ma',
    'kuehn,e': 'kuhn,e',
    'davidsen,c': 'davidson,c',
    'estabrook': 'estabrook,gf',
    'sousa,tc': 'souza,tc',
    'verwimp': 'verwimp,i',
    'campos,jmf': 'campos,jmp',
    'silva,lm': 'silva,lam',
    'smith,l': 'smith,lb',
    'yamomoto,m': 'yamamoto,m',
    'verveloet,rr': 'vervloet,rr',
    'rocha,rm': 'rocha,rn',
    'oliveira,nr': 'oliveira,nro',
    'haas,jh': 'hass,jh',
    'whalen,a': 'whalen,aj',
    'sa,spp': 'sa,spps',
    'bensusan,n': 'bensusan,nr',
    'borgato,df': 'borgatto,df',
    'mendes,jn': 'mendes,jm',
    'fontella,j': 'fontella,jp',
    'staggemeier,vg': 'staggmeier,vg',
    'campos,mtv': 'campos,mtva',
    'benton,f': 'benton,fp',
    'marchioni,jm': 'marchiori,jn',
    'juchum': 'juchum,f',
    'peocopio,lc': 'procopio,lc',
    'romeroc': 'romero,c', 
    'marques,c': 'marques,cf',
    'cardoso,ef': 'cardoso,f',
    'pereira,ba': 'pereira,bas',
    'carvalho,sl': 'carvalho-leite,sl', 
    'carvalholeite,sl': 'carvalho-leite,sl',
    'benedete': 'benedete,al',
    'harley,gm': 'harley,rm',
    'diasmelo,r': 'dias-melo,r', 
    'melo,rd': 'dias-melo,r',
    'schiesinki': 'schiesinski,d',
    'porto,jr': 'porto,jlr',
    'argent,g': 'argent,gcg',
    'argentgcgin': 'argent,gcg',
    'rodri': 'rodrig',
    'araujo,g': 'araujo,gm',
    'carvalho,amv': 'carvalho,avm',
    'carvalho,am': 'carvalho,avm', 
    'carvalho,amv': 'carvalho,avm',
    'careno,s': 'carreno,s',
    'mazine,f': 'mazine-capelo,ff', 
    'mazinecapelo,ff': 'mazine-capelo,ff',
    'lopes,i': 'lopes,isn',
    'irvine,gc': 'irwine,cg',
    'taroda,n': 'tarroda,n',
    'isejima': 'isejima,em',
    'dario,f': 'dario,fr',
    'onishi': 'onishi,e',
    'sidney': 'sidney,gf',
    'reitz': 'reitz,pr',
    'devogel,ef': 'vogel,hvf',
    'borges,j': 'borges,jwm',
    'brade': 'brade,ac',
    'nicacio': 'nicacio,jn',
    'anapaula': 'ana-paula', 
    'paula,a': 'ana-paula',
    'dell,d': 'odell,d',
    'rondon': 'rondon,c',
    'santos,h': 'santos,hcf',
    'furla': 'furlan,a',
    'grasser,g': 'grasser,ga',
    'pedrosa,ma': 'pedroso,ma',
    'pedrosa,n': 'pedrosa,ns',
    'zoccoli,d': 'zoccoli,dm',
    'arroyo,mtk': 'kallin-arroyo,mt', 
    'kallinarroyo,mt': 'kallin-arroyo,mt', 
    'brito,ic': 'britto,ic',
    'degrande,da': 'grande,da',
    'sales,sc': 'salles,sc',
    'souza,r': 'souza,rr',
    'guedes,j': 'guedes,jc',
    'herlan,j': 'herlanio,j',
    'nascimento,a': 'nascimento,ae',
    'siva,ma': 'silva,ma',
    'bucci,f': 'bucci,ffb',
    'santana,bdi': 'santana,bid',
    'giordano,lc': 'giordano,lcs',
    'meyer': 'meyer,fs',
    'franca': 'franca,f', 
    'koekemoer,m': 'koekomoer,m',
    'souza,rt': 'souza,rtc',
    'pereira,t': 'pereira,ta',
    'jose,m': 'jose,maria',
    'carmo,j': 'carmo,jj',
    'fernandes,a': 'fernandes,ag',
    'moraes,plr': 'moraes,prl',
    'maia,w': 'maia,wd',
    'martins,ca': 'martins,can',
    'polite,l': 'politi,l',
    'almeida,f': 'almeida,fc',
    'borges,jw': 'borges,jwm',
    'kuhlman,m': 'kuhlmann,m',
    'silva,mb': 'silva,mib', 
    'sousa,rv': 'souza,rv',
    'koczichi': 'koczicki,c',
    'leite,jr': 'leite,jrs',
    'silva,pit': 'tanno-silva,pi',
    'tannosilva,pi': 'tanno-silva,pi',
    'mendonca,r': 'mendonca,rc',
    'mendonca,rr': 'mendonca,rc',
    'schumke,j': 'schunke,j',
    'abe,lb': 'abe,lm',
    'reitz': 'reitz,r',
    'stieber,m': 'stieber,mt',
    'sieber,m': 'stieber,mt',
    'chagasesilva,fc': 'chagas-e-silva,fc', 
    'chagasesilva,f': 'chagas-e-silva,fc',
    'silva,fc': 'chagas-e-silva,fc',
    'prance,g': 'prance,gt',
    'melo,trb': 'mello,trb', 
    'sena,pac': 'senna,pac',
    'pereira,l': 'pereira,la',
    'caneiro,j': 'carneiro,j',
    'munhoz,ca': 'munhoz,cbr',
    'jimenez': 'jimenez,ja',
    'castellanos': 'castellanos,a',
    'cristobal,l': 'cristobal,cl', 
    'sousa,ng': 'souza,ng',
    'westra,lyt': 'westra,lyth',
    'luna,ta': 'luna,ti',
    'pilger': 'pilges',
    'silva,mi': 'silva,mib',
    'mitzi': 'mitzi,g',
    'santos,rr': 'santos,rrb',
    'morales,r': 'morales,rav',
    'sidney': 'sidnei,rm', 
    'siva,ja': 'silva,ja', 
    'vitti,f': 'vitti,fx',
    'oliveira,fac': 'oliveira,fca',
    'landrum,s': 'landrum,ss',
    'rodrigues,wa': 'rodrigues,wm',
    'bromley,g': 'bomley,gl', 
    'constable,ef': 'constable,ej',
    'armando,m': 'armando,ms',
    'falcao,ji': 'falcao,jia',
    'maroccolo,jf': 'marocollo,jf',
    'maxwell,h': 'maxwell,hh',
    'zaruchi': 'zarucchi,j', 
    'santos,mcv': 'vilela-santos,mc', 
    'vilelasantos,mc': 'vilela-santos,mc',
    'silva,eb': 'silva,ebm',
    'jumbo,s': 'jimbo,s', 
    'medeiros,l': 'medeiros,lb',
    'johnson,l': 'johnson,las',
    'franciso,em': 'francisco,em', 
    'melo': 'melo,e',
    'nogueira,lm': 'nogueira,lmg',
    'aquino,f': 'aquino,fg',
    'cairus,rjr': 'cairos,rjr',
    'santos,aj': 'santos,ajv',
    'cerqueira,ls': 'cerqueira,lsc',
    'fonseca,rr': 'fonseca,s',
    'fonseca,sg': 'fonseca,s',
    'fonseca,rr': 'fonseca,s',
    'fonseca,sf': 'fonseca,s',
    'fonseca,fs': 'fonseca,s',
    'fonseca,fj': 'fonseca,j',
    'fonseca,l': 'fonseca,lm',
    'vilar,ts': 'villar,ts',
    'colleta,gd': 'colletta,gd',
    'barker,r': 'barker,rm',
    'fragg,c': 'fagg,cw', 
    'fagg,c': 'fagg,cw',
    'pennigton,td': 'pennington,td',
    'rivera,v': 'rivera,vl',
    'smya,s': 'sumya,s',
    'versiane,af': 'versiane,afa',
    'castelo,aj': 'castro,aj',
    'richards': 'richardspwin',
    'richards,m': 'richardspwin',
    'richards,pw': 'richardspwin',
    'pinheiro,s': 'pinheiros,s',
    'pinheiro,em': 'pinheiros,em',
    'lima,e': 'lima,es',
    'hind,dj': 'hind,djn',
    'hind,n': 'hind,djn', 
    'soares,g': 'soares,gf',
    'ferreira,map': 'pereira,map',
    'dobereiner': 'dobereiner,j',
    'scariot,a': 'scariot,ao',
    'monteiro,r': 'monteiro,rn',
    'leal,cg': 'leal,g',
    'garcia,mcm': 'garcia,mgm',
    'lopes,wdp': 'lopes,wp',
    'oliveira,m': 'oliveira,ms',
    'vinha,s': 'vinha,sg',
    'santos,g': 'santos,gb',
    'filgueira,ts': 'filgueiras,ts',
    'stutte,jg': 'stutts,jg',
    'stutte,j': 'stutts,jg',
    'stutts,j': 'stutts,jg',
    'shutts,jg': 'stutts,jg',
    'garcia,pb': 'garcia,pbc',
    'joaovicente': 'vicente,j',
    'mariz,g': 'mariza,g',
    'fierros,af': 'freire-fierros,a', 
    'freirefierros,a': 'freire-fierros,a',
    'rodrigues,ce': 'rodrigues-junior,ce', 
    'rodriguesjunior,ce': 'rodrigues-junior,ce',
    'kirkbridejunior,j': 'kirkbride-junior,jh', 
    'kirkbridejunior,jh': 'kirkbride-junior,jh',
    'kirkbride,jh': 'kirkbride-junior,jh',
    'souza,rs': 'sousa,rs',
    'belizario,m': 'belisario,m',
    'gibles,p': 'gibbs,pe', 
    'black': 'black,ga',
    'black,g': 'black,ga',
    'black,ca': 'black,ga',
    'szechy,mtm': 'sechy,mts', 
    'ladeira,j': 'ladeira,jl',
    'kauseilmari':'kause,i', 
    'rodrigues,w': 'rodrigues,wm',
    'marines,g': 'marinis,g',
    'maranis,g': 'marinis,g',
    'bromley,g': 'bromley,gl',
    'barbosa,ea': 'barbosa,e', 
    'leitaofilho,h':'leitao-filho,h',
    'leitao,hf': 'leitao-filho,h',
    'leitaofilho,hf':'leitao-filho,h',
    'nilsson,s': 'nilson,s', 
    'mirizawa,m': 'kirizawa,m',
    'gomes,v': 'gomes,vl',
    'leite,jra': 'leite,jrs',
    'philcox': 'philcox,d',
    'dutil,jh': 'dutilh,jha',
    'arraes,mgm': 'arrais,mgm',
    'soderstrom': 'soderstrom,tr',
    'raulino,t': 'raulino,taf',
    'cisnero,la': 'cisneros,la',
    'santos,f': 'santos,gf',
    'santos,fm': 'santos,fam',
    'santos,ffm': 'santos,fam',
    'wasshusen,dc': 'wasshausen,dc', 
    'fereira,a': 'ferreira,a',
    'freitas,g': 'freitas,gs',
    'oliveira,fca': 'oliveira,fcao',
    'cervi,ac': 'cervi,ca',
    'wilsonbrowne,g': 'browne,gw', 
    'ribeiro,mm': 'ribeiro,mmv',
    'boom,b': 'boom,bm',
    'amorim,pr': 'amorim,prf',
    'amorim,p': 'amorim,prf',
    'lannasobrinho,jp': 'lana-sobrinho,jp',
    'lanasobrinho,jp': 'lana-sobrinho,jp',
    'sobrinho,jpl': 'lana-sobrinho,jp',
    'pires,jm': 'pires,jn',
    'pires,jf': 'pires,jn',
    'fereira,a': 'ferreira,a',
    'bomley,gl': 'bromley,gl',
    'dusi,rl': 'dusi,rlm',
    'assuncao,pacl': 'assuncao,pac',
    'assunsao,paci': 'assuncao,pac',
    'assuncao,pacs': 'assuncao,pac',
    'assuncao,pa': 'assuncao,pac',
    'hathome,w': 'hawthorne,w',
    'sendullsky,t': 'sendulsky,t',
    'caixetadedeus,w': 'caixeta,w',
    'vicente,j': 'vicente,jc',
    'alavarenga,d': 'alvarenga,d',
    'fontella,jp': 'fontella,pj',
    'andrade,p': 'andrade,pm',
    'rizzini': 'rizzini,ct',
    'barbosa,ma': 'barboza,ma',
}

# %%
nm.remap(remap)
nm.getMap()
# Out:
# {'.': '',
#  '1980 Sino-Amer Exped.': 'sinoamerexped',
#  '?': '',
#  'A.J.N.V.': 'ajnv',
#  'A.M.': 'am',
#  'Abbas, B': 'abbas,b',
#  'Abdala, GC': 'abdala,gc',
#  'Abdo, MSA': 'abdo,msa',
#  'Abdon': 'abdon',
#  'Abe, LB': 'abe,lm',
#  'Abe, LM': 'abe,lm',
#  'Abrahim, MA': 'abrahim,ma',
#  'Abreu, CG': 'abreu,cg',
#  'Abreu, GX': 'abreu,gx',
#  'Abreu, I': 'abreu,i',
#  'Abreu, LC': 'abreu,lcr',
#  'Abreu, LCR': 'abreu,lcr',
#  'Abreu, M': 'abreu,mc',
#  'Abreu, MC': 'abreu,mc',
#  'Abreu, MS': 'abreu,mc',
#  'Abreu, NL': 'abreu,nl',
#  'Abreu, NR': 'abreu,nr',
#  'Abreu, TLS': 'abreu,tls',
#  'Accioly': 'accioly',
#  'Accorsi, WR': 'accorsi,wr',
#  'Acera, V': 'acera,v',
#  'Acevedo-Rodriguez, P': 'acevedorodriguez,p',
#  'Acuña, BC': 'acuna,bc',
#  'Adams, WP': 'adams,wp',
#  'Adcock, S': 'adcock,s',
#  'Adderley, LS': 'adderley,ls',
#  'Addison, G': 'addison,g',
#  'Addor, EE': 'addor,ee',
#  'Adler': 'adler',
#  'Adorno, H': 'adorno,h',
#  'Adão': 'adao',
#  'Aedo, C': 'aedo,c',
#  'Affonso, P': 'affonso,p',
#  'Afonso, AA': 'afonso,aa',
#  'Afonso, AP': 'afonso,ap',
#  'Agenor': 'agenor',
#  'Aguiar, AC': 'aguiar,aca',
#  'Aguiar, ACA': 'aguiar,aca',
#  'Aguiar, AJC': 'aguiar,ajc',
#  'Aguiar, AM': 'aguiar,am',
#  'Aguiar, AN': 'aguiar,an',
#  'Aguiar, C': 'aguiar,c',
#  'Aguiar, E': 'aguiar,e',
#  'Aguiar, OT': 'aguiar,ot',
#  'Aguiar, P': 'aguiar,p',
#  'Aguiar, SNF': 'aguiar,snf',
#  'Aguilar, R': 'aguilar,r',
#  'Aguirre, GH': 'aguirre,gh',
#  'Ahti, T': 'ahti,t',
#  'Ahumada, Z': 'ahumada,z',
#  'Aires, CA': 'aires,ca',
#  'Aires, DA': 'aires,da',
#  'Aires, J': 'aires,j',
#  'Aires, RC': 'aires,rc',
#  'Aires, SL': 'aires,sl',
#  'Akisul, G': 'akisul,g',
#  'Akiyama, H': 'akiyama,h',
#  'Alain': 'alain',
#  'Alamo, FG': 'alamo,fg',
#  'Alava, A': 'alava,a',
#  'Alava, R': 'alava,r',
#  'Alavarenga, D': 'alvarenga,d',
#  'Albiero, A': 'albiero,a',
#  'Albino, BV': 'albino,bv',
#  'Albino, RS': 'albino,rs',
#  'Albright, R': 'albright,r',
#  'Albuquerque, BWP': 'albuquerque,bwp',
#  'Albuquerque, JM': 'albuquerque,jm',
#  'Albuquerque, M': 'albuquerque,m',
#  'Albuquerque, V': 'albuquerque,v',
#  'Albuquerque, VBA': 'albuquerque,vba',
#  'Albuquerque, VR': 'albuquerque,vr',
#  'Alcina': 'alcina',
#  'Alcock, CR': 'alcock,cr',
#  'Alcoforado Filho, FG': 'alcoforadofilho,fg',
#  'Alcântara': 'alcantara',
#  'Alcântara, MB': 'alcantara,mb',
#  'Alcântara, TH': 'alcantara,th',
#  'Alecrim, MC': 'alecrim,mc',
#  'Aleixo, R': 'aleixo,r',
#  'Alencar, A': 'alencar,a',
#  'Alencar, KMC': 'alencar,kmc',
#  'Alencar, L': 'alencar,l',
#  'Alencar, ME': 'alencar,me',
#  'Alencar, T': 'alencar,t',
#  'Alencastro, A': 'alencastro,a',
#  'Alessandro': 'alessandro',
#  'Alexandre, MT': 'alexandre,mt',
#  'Alfaro, E': 'alfaro,e',
#  'Alho, K': 'alho,k',
#  'Alho, R': 'alho,r',
#  'Aline': 'aline',
#  'Alkimim, W': 'alkimim,w',
#  'Allan, KM': 'allan,km',
#  'Allard, HA': 'allard,ha',
#  'Allem, A': 'allem,ac',
#  'Allem, AC': 'allem,ac',
#  'Allem, LN': 'allem,ln',
#  'Allen, B': 'allen,b',
#  'Allen, GH': 'allen,gh',
#  'Allen, JA': 'allen,ja',
#  'Allender, MJ': 'allender,mj',
#  'Allevato, SR': 'allevato,sr',
#  'Allorge, L': 'allorge,l',
#  'Almeda, F': 'almeda,f',
#  'Almeida, AA': 'almeida,aa',
#  'Almeida, C': 'almeida,c',
#  'Almeida, COS': 'almeida,cos',
#  'Almeida, EF': 'almeida,ef',
#  'Almeida, F': 'almeida,fc',
#  'Almeida, FC': 'almeida,fc',
#  'Almeida, FM': 'almeida,fm',
#  'Almeida, GEM': 'almeida,gem',
#  'Almeida, GSC': 'almeida,gsc',
#  'Almeida, J': 'almeida,j',
#  'Almeida, JC': 'almeida,jc',
#  'Almeida, JGL': 'almeida,jgl',
#  'Almeida, JV': 'almeida,jv',
#  'Almeida, L': 'almeida,l',
#  'Almeida, LP': 'almeida,lp',
#  'Almeida, M': 'almeida,m',
#  'Almeida, MC': 'almeida,mc',
#  'Almeida, MIQ': 'almeida,miq',
#  'Almeida, MR': 'almeida,mr',
#  'Almeida, RC': 'almeida,rc',
#  'Almeida, RE': 'almeida,re',
#  'Almeida, RF': 'almeida,rf',
#  'Almeida, RJ': 'almeida,rj',
#  'Almeida, S': 'almeida,s',
#  'Almeida, SMS': 'almeida,sms',
#  'Almeida, SP': 'almeida,sp',
#  'Almeida, SS': 'almeida,ss',
#  'Almeida, TE': 'almeida,te',
#  'Almeida, VR': 'almeida,vr',
#  'Almeida-Scabbia, RJ': 'almeidascabbia,rj',
#  'Aloisi, J': 'aloisi,j',
#  'Alreo, M': 'alreo,m',
#  'Altamiro': 'altamiro',
#  'Althoff, KC': 'althoff,kc',
#  'Alunos Bot III': 'alunosbotiii',
#  'Alunos de Biologia IV': 'alunosdebiologiaiv',
#  'Alunos de Sistemática Vegetal': 'alunosdesistematicavegetal',
#  'Alvarenga, A': 'alvarenga,a',
#  'Alvarenga, D': 'alvarenga,d',
#  'Alvarenga, FG': 'alvarenga,fg',
#  'Alvarenga, L': 'alvarenga,l',
#  'Alvarenga, M': 'alvarenga,m',
#  'Alves Júnior, C': 'alvesjunior,c',
#  'Alves, AF': 'alves,af',
#  'Alves, AG': 'alves,ag',
#  'Alves, AS': 'alves,as',
#  'Alves, ASA': 'alves,asa',
#  'Alves, CA': 'alves,ca',
#  'Alves, FM': 'alves,fm',
#  'Alves, FQ': 'alves,fq',
#  'Alves, GKJ': 'alves,gkj',
#  'Alves, H': 'alves,h',
#  'Alves, J': 'alves,j',
#  'Alves, JH': 'alves,jh',
#  'Alves, JLH': 'alves,jlh',
#  'Alves, L': 'alves,l',
#  'Alves, LC': 'alves,lc',
#  'Alves, LF': 'alves,lf',
#  'Alves, LM': 'alves,lm',
#  'Alves, LQ': 'alves,lq',
#  'Alves, M': 'alves,m',
#  'Alves, MA': 'alves,ma',
#  'Alves, MAS': 'alves,mas',
#  'Alves, MC': 'alves,mc',
#  'Alves, MM': 'alves,mm',
#  'Alves, MV': 'alves,mv',
#  'Alves, PD': 'alves,pd',
#  'Alves, RBN': 'alves,rbn',
#  'Alves, RNB': 'alves,rnb',
#  'Alves, RR': 'alves,rr',
#  'Alves, RU': 'alves,ru',
#  'Alves, SAM': 'alves,sam',
#  'Alves, SRT': 'alves,srt',
#  'Alves, T': 'alves,t',
#  'Alvim, LC': 'alvim,lc',
#  'Alvim, MB': 'alvim,mb',
#  'Alvin, P': 'alvin,p',
#  'Amado, TF': 'amado,tf',
#  'Amador, DB': 'amador,db',
#  'Amaral Júnior, A': 'amaraljunior,a',
#  'Amaral, A': 'amaral,a',
#  'Amaral, AC': 'amaral,ac',
#  'Amaral, AF': 'amaral,af',
#  'Amaral, AG': 'amaral,ag',
#  'Amaral, AS': 'amaral,as',
#  'Amaral, BR': 'amaral,br',
#  'Amaral, E': 'amaral,e',
#  'Amaral, IL': 'amaral,il',
#  'Amaral, JP': 'amaral,jp',
#  'Amaral, LG': 'amaral,lg',
#  'Amaral, MC': 'amaral,mc',
#  'Amaral, MCE': 'amaral,mce',
#  'Amaral, MF': 'amaral,mf',
#  'Amaral, RC': 'amaral,rc',
#  'Amaral, TS': 'amaral,ts',
#  'Amaral, WAN': 'amaral,wan',
#  'Amaury': 'amaury',
#  'Amdursky, I': 'amdursky,i',
#  'Amenomori, SN': 'amenomori,sn',
#  'Amorim Neto, L': 'amorimneto,l',
#  'Amorim, A': 'amorim,a',
#  'Amorim, AH': 'amorim,ah',
#  'Amorim, AM': 'amorim,am',
#  'Amorim, AMA': 'amorim,ama',
#  'Amorim, EH': 'amorim,eh',
#  'Amorim, L': 'amorim,l',
#  'Amorim, ME': 'amorim,me',
#  'Amorim, P': 'amorim,prf',
#  'Amorim, PR': 'amorim,prf',
#  'Amorim, PRF': 'amorim,prf',
#  'Amorim, SF': 'amorim,sf',
#  'Ana': 'ana',
#  'Ana Angélica': 'anaangelica',
#  'Ana Clara': 'anaclara',
#  'Ana Luíza': 'analuiza',
#  'Ana Paula': 'ana-paula',
#  'Ana, Lima': 'ana,lima',
#  'Anael': 'anael',
#  'Anastacio': 'anastacio',
#  'Ancelmo': 'ancelmo',
#  'Andahur, JP': 'andahur,jp',
#  'Anderson, C': 'anderson,c',
#  'Anderson, H': 'anderson,h',
#  'Anderson, HS': 'anderson,hs',
#  'Anderson, JL': 'anderson,jl',
#  'Anderson, L': 'anderson,l',
#  'Anderson, LE': 'anderson,le',
#  'Anderson, P': 'anderson,p',
#  'Anderson, W': 'anderson,w',
#  'Anderson, WR': 'anderson,wr',
#  'Andersson, L': 'andersson,l',
#  'Ando, N': 'ando,n',
#  'Andrade, A': 'andrade,a',
#  'Andrade, AM': 'andrade,am',
#  'Andrade, BS': 'andrade,bs',
#  'Andrade, CCA': 'andrade,cca',
#  'Andrade, CT': 'andrade,ct',
#  'Andrade, JB': 'andrade,jb',
#  'Andrade, JC': 'andrade,jc',
#  'Andrade, KA': 'andrade,ka',
#  'Andrade, LAA': 'andrade,laa',
#  'Andrade, LAZ': 'andrade,laz',
#  'Andrade, LD': 'andrade,ld',
#  'Andrade, MAR': 'andrade,mar',
#  'Andrade, MC': 'andrade,mc',
#  'Andrade, MD': 'andrade,md',
#  'Andrade, MJG': 'andrade,mjg',
#  'Andrade, NF': 'andrade,nf',
#  'Andrade, P': 'andrade,pm',
#  'Andrade, PM': 'andrade,pm',
#  'Andrade, S': 'andrade,s',
#  'Andrade, SF': 'andrade,sf',
#  'Andrade, SMM': 'andrade,smm',
#  'Andrade-Lima, D': 'andradelima,d',
#  'Andrea': 'andrea',
#  'Andrea, M': 'andrea,m',
#  'Andrelinho': 'andrelinho',
#  'Andrews, HH': 'andrews,hh',
#  'Andrikopoll, F': 'andrikopoll,f',
#  'André': 'andre',
#  'Angarten, NBO': 'angarten,nbo',
#  'Angeli, C': 'angeli,c',
#  'Angélica': 'angelica',
#  'Anhanguera, UL': 'anhanguera,ul',
#  'Anjos, ER': 'anjos,er',
#  'Anjos, JRN': 'anjos,jrn',
#  'Anjos, VC': 'anjos,vc',
#  'Annunziata, BB': 'annunziata,bb',
#  'Antezana, FL': 'antezana,fl',
#  'Antonio': 'antonio',
#  'Antonio, T': 'antonio,t',
#  'Antonio, TM': 'antonio,tm',
#  'Antoniolli, FC': 'antoniolli,fc',
#  'Antunes, EC': 'antunes,ec',
#  'Antunes, J': 'antunes,j',
#  'Antunes, K': 'antunes,k',
#  'Antunes, LL': 'antunes,ll',
#  'Antunes, LLC': 'antunes,llc',
#  'Antunes, NB': 'antunes,nb',
#  'Antunes, RM': 'antunes,rm',
#  'Antônio, M': 'antonio,m',
#  'Anunciação, AE': 'anunciacao,ae',
#  'Aona, LYS': 'aona,lys',
#  'Aparecida da Silva, M': 'aparecidadasilva,m',
#  'Aplin, TEH': 'aplin,teh',
#  'Aponte, CH': 'aponte,ch',
#  'Apparício': 'apparicio',
#  'Aquilante, DJ': 'aquilante,dj',
#  'Aquino, C': 'aquino,c',
#  'Aquino, F': 'aquino,fg',
#  'Aquino, FG': 'aquino,fg',
#  'Aquino, M': 'aquino,m',
#  'Aquino, PAN': 'aquino,pan',
#  'Aquino, PPU': 'aquino,ppu',
#  'Aquino, PPV': 'aquino,ppv',
#  'Aquino, R': 'aquino,r',
#  'Arae, F': 'arae,f',
#  'Aragaki, S': 'aragaki,s',
#  'Aragona, L': 'aragona,l',
#  'Aragona, M': 'aragona,m',
#  'Aragone': 'aragone',
#  'Aragão, F': 'aragao,f',
#  'Aragão, I': 'aragao,i',
#  'Aragão, JG': 'aragao,jg',
#  'Araki, DF': 'araki,df',
#  'Aranha Filho, JLM': 'aranhafilho,jlm',
#  'Aranha, BA': 'aranha,ba',
#  'Aranha, C': 'aranha,c',
#  'Arantes, A': 'arantes,a',
#  'Arantes, AA': 'arantes,aa',
#  'Arantes, C': 'arantes,c',
#  'Araujo, AC': 'araujo,ac',
#  'Araujo, AG': 'araujo,ag',
#  'Araujo, AO': 'araujo,ao',
#  'Araujo, GB': 'araujo,gb',
#  'Araujo, GM': 'araujo,gm',
#  'Araujo, J': 'araujo,j',
#  'Araujo, RC': 'araujo,rc',
#  'Araujo, S': 'araujo,s',
#  'Araújo, AFB': 'araujo,afb',
#  'Araújo, AFP': 'araujo,afp',
#  'Araújo, AG': 'araujo,ag',
#  'Araújo, AMS': 'araujo,ams',
#  'Araújo, AO': 'araujo,ao',
#  'Araújo, AP': 'araujo,ap',
#  'Araújo, CM': 'araujo,cm',
#  'Araújo, CO': 'araujo,co',
#  'Araújo, CSF': 'araujo,csf',
#  'Araújo, D': 'araujo,d',
#  'Araújo, DA': 'araujo,da',
#  'Araújo, DSD': 'araujo,dsd',
#  'Araújo, F': 'araujo,f',
#  'Araújo, FD': 'araujo,fd',
#  'Araújo, FP': 'araujo,fp',
#  'Araújo, FS': 'araujo,fs',
#  'Araújo, G': 'araujo,gm',
#  'Araújo, GM': 'araujo,gm',
#  'Araújo, GP': 'araujo,gp',
#  'Araújo, GS': 'araujo,gs',
#  'Araújo, I': 'araujo,i',
#  'Araújo, JE': 'araujo,je',
#  'Araújo, JS': 'araujo,js',
#  'Araújo, LH': 'araujo,lh',
#  'Araújo, LM': 'araujo,lm',
#  'Araújo, M': 'araujo,m',
#  'Araújo, MF': 'araujo,mf',
#  'Araújo, MI': 'araujo,mi',
#  'Araújo, RF': 'araujo,rf',
#  'Araújo, RS': 'araujo,rs',
#  'Araújo, SC': 'araujo,sc',
#  'Araújo, TF': 'araujo,tf',
#  'Araújo, TOP': 'araujo,top',
#  'Araújo, WS': 'araujo,ws',
#  'Arbelaez, EP': 'arbelaez,ep',
#  'Arbex, LH': 'arbex,lh',
#  'Arbo, MM': 'arbo,mm',
#  'Arcanjo Pinheiro': 'arcanjopinheiro',
#  'Arcanjo, D': 'arcanjo,d',
#  'Arcanjo, M': 'arcanjo,m',
#  'Arcela, V': 'arcela,v',
#  'Archer, W': 'archer,w',
#  'Archer, WA': 'archer,wa',
#  'Archer, WH': 'archer,wh',
#  'Areias, CA': 'areias,ca',
#  'Areira, J': 'areira,j',
#  'Argent G.C.G.': 'argentgcg',
#  'Argent G.C.G. in': 'argent,gcg',
#  'Argent, G': 'argent,gcg',
#  'Argent, GCG': 'argent,gcg',
#  'Arima, EY': 'arima,ey',
#  'Arima, LIA': 'arima,lia',
#  'Arimoro, O': 'arimoro,o',
#  'Aristeguieta, L': 'aristeguieta,l',
#  'Arlindo': 'arlindo',
#  'Armando, M': 'armando,ms',
#  'Armando, MS': 'armando,ms',
#  'Armbruster, WS': 'armbruster,ws',
#  'Arnaldo': 'arnaldo',
#  'Arnell, HW': 'arnell,hw',
#  'Arnold': 'arnold',
#  'Arnold, T': 'arnold,t',
#  'Arouck, J': 'arouck,j',
#  'Arraes, MG': 'arraes,mg',
#  'Arraes, MGM': 'arrais,mgm',
#  'Arrais, MGM': 'arrais,mgm',
#  'Arroyo': 'arroyo',
#  'Arroyo, MTK': 'kallin-arroyo,mt',
#  'Arruda, AJ': 'arruda,aj',
#  'Arruda, EC': 'arruda,ec',
#  'Arruda, ML': 'arruda,ml',
#  'Arruda, MLR': 'arruda,mlr',
#  'Arruda, R': 'arruda,r',
#  'Arruda, VR': 'arruda,vr',
#  'Arruda, WS': 'arruda,ws',
#  'Arsene': 'arsene',
#  'Arts, T': 'arts,t',
#  'Arvher, W': 'arvher,w',
#  'Arzolla, FARDP': 'arzolla,fardp',
#  'Arzolla, FARP': 'arzolla,farp',
#  'Ascendino, AA': 'ascendino,aa',
#  'Aschan, N': 'aschan,n',
#  'Ashlee, TR': 'ashlee,tr',
#  'Ashton, EM': 'ashton,em',
#  'Assis, A': 'assis,a',
#  'Assis, AM': 'assis,am',
#  'Assis, CM': 'assis,cm',
#  'Assis, JS': 'assis,js',
#  'Assis, LCS': 'assis,lcs',
#  'Assis, M': 'assis,m',
#  'Assis, MA': 'assis,ma',
#  'Assis, MC': 'assis,mc',
#  'Assis, TS': 'assis,ts',
#  'Assis, V': 'assis,v',
#  'Assumpção, D': 'assumpcao,d',
#  'Assumpção, S': 'assumpcao,s',
#  'Assunsão, MM': 'assunsao,mm',
#  'Assunsão, PACI': 'assuncao,pac',
#  'Assunção, PA': 'assuncao,pac',
#  'Assunção, PACL': 'assuncao,pac',
#  'Assunção, PACS': 'assuncao,pac',
#  'Assunção, S': 'assuncao,s',
#  'Assunção, V': 'assuncao,v',
#  'Assunção, VA': 'assuncao,va',
#  'Astle, WL': 'astle,wl',
#  'Astorino, A': 'astorino,a',
#  'Atala, F': 'atala,f',
#  'Atayde, P': 'atayde,p',
#  'Ataíde, M': 'ataide,m',
#  'Athaide, P': 'athaide,p',
#  'Athayde Filho, FP': 'athaydefilho,fp',
#  'Atkins, S': 'atkins,s',
#  'Atkinson, R': 'atkinson,r',
#  'Atta, ALV': 'atta,alv',
#  'Atta, AVL': 'atta,avl',
#  'Attala, NC': 'attala,nc',
#  'Atwood, J': 'atwood,j',
#  'Auad, MV': 'auad,mv',
#  'Aubreville, A': 'aubreville,a',
#  'Audenis, C': 'audenis,c',
#  'Auer, AV': 'auer,av',
#  'Augusto, J': 'augusto,j',
#  'Augusto, MM': 'augusto,mm',
#  'Aulino, O': 'aulino,o',
#  'Aura, A': 'aura,a',
#  'Aurélio': 'aurelio',
#  'Aurélio Silva, M': 'aureliosilva,m',
#  'Avelar, MG': 'avelar,mg',
#  'Avelar, P': 'avelar,p',
#  'Avila, MV': 'avila,mv',
#  'Ayala, F': 'ayala,f',
#  'Ayansu': 'ayansu',
#  'Ayedem, N': 'ayedem,n',
#  'Ayre, AM': 'ayre,am',
#  'Azevedo': 'azevedo',
#  'Azevedo, AA': 'azevedo,aa',
#  'Azevedo, D': 'azevedo,d',
#  'Azevedo, EP': 'azevedo,ep',
#  'Azevedo, F': 'azevedo,f',
#  'Azevedo, GR': 'azevedo,gr',
#  'Azevedo, IM': 'azevedo,im',
#  'Azevedo, INC': 'azevedo,inc',
#  'Azevedo, MLM': 'azevedo,mlm',
#  'Azevedo, V': 'azevedo,v',
#  'Bacci, LF': 'bacci,lf',
#  'Bach, J': 'bach,j',
#  'Badcock': 'badcock',
#  'Badini, J': 'badini,j',
#  'Baeza, CM': 'baeza,cm',
#  'Baeza, P': 'baeza,p',
#  'Bagalhi, E': 'bagalhi,e',
#  'Bagato, D': 'bagato,d',
#  'Bahia, RP': 'bahia,rp',
#  'Bahia, TR': 'bahia,tr',
#  'Bailey, FM': 'bailey,fm',
#  'Bailey, WM': 'bailey,wm',
#  'Baitello, JB': 'baitello,jb',
#  'Baker, J': 'baker,j',
#  'Baker, JG': 'baker,jg',
#  'Baker, MS': 'baker,ms',
#  'Balbino, V': 'balbino,v',
#  'Balbuena, C': 'balbuena,c',
#  'Baldwin Junior, JT': 'baldwinjunior,jt',
#  'Baleeiro, P': 'baleeiro,p',
#  'Balegno, B': 'balegno,b',
#  'Balfour': 'balfour',
#  'Balgooy, MMJ': 'balgooy,mmj',
#  'Balick, MJ': 'balick,mj',
#  'Balslev, H': 'balslev,h',
#  'Baltzell, L': 'baltzell,l',
#  'Bandeira, FP': 'bandeira,fp',
#  'Bankoff, P': 'bankoff,p',
#  'Bao, F': 'bao,f',
#  'Baptista, CB': 'baptista,cb',
#  'Baptista, MLL': 'baptista,mll',
#  'Baracat, C': 'baracat,c',
#  'Baracot, C': 'baracot,c',
#  'Baracot, LCH': 'baracot,lch',
#  'Barahona, E': 'barahona,e',
#  'Barbarioli Neto, M': 'barbariolineto,m',
#  'Barbaro, D': 'barbaro,d',
#  'Barbiellini, AA': 'barbiellini,aa',
#  'Barbosa': 'barbosa',
#  'Barbosa Rodrigues, S': 'barbosarodrigues,s',
#  'Barbosa, A': 'barbosa,a',
#  'Barbosa, AA': 'barbosa,aa',
#  'Barbosa, AAA': 'barbosa,aaa',
#  'Barbosa, ACF': 'barbosa,acf',
#  'Barbosa, AM': 'barbosa,am',
#  'Barbosa, AR': 'barbosa,ar',
#  'Barbosa, C': 'barbosa,c',
#  'Barbosa, E': 'barbosa,e',
#  'Barbosa, EA': 'barbosa,e',
#  'Barbosa, HN': 'barbosa,hn',
#  'Barbosa, J': 'barbosa,j',
#  'Barbosa, JC': 'barbosa,jc',
#  'Barbosa, JM': 'barbosa,jm',
#  'Barbosa, JP': 'barbosa,jp',
#  'Barbosa, LF': 'barbosa,lf',
#  'Barbosa, LMQ': 'barbosa,lmq',
#  'Barbosa, M': 'barbosa,m',
#  'Barbosa, M.G.': 'barbosa,mg',
#  'Barbosa, MA': 'barboza,ma',
#  'Barbosa, MM': 'barbosa,mm',
#  'Barbosa, MR': 'barbosa,mr',
#  'Barbosa, NF': 'barbosa,nf',
#  'Barbosa, NM': 'barbosa,nm',
#  'Barbosa, T': 'barbosa,t',
#  'Barbosa, VP': 'barbosa,vp',
#  'Barbosa-Silva, D': 'barbosasilva,d',
#  'Barboza, C': 'barboza,c',
#  'Barboza, E': 'barboza,e',
#  'Barboza, EA': 'barboza,ea',
#  'Barboza, MA': 'barboza,ma',
#  'Barcia, J': 'barcia,j',
#  'Bardelli, KC': 'bardelli,kc',
#  'Barghoorn, E': 'barghoorn,e',
#  'Barino, GTM': 'barino,gtm',
#  'Barker, R': 'barker,rm',
#  'Barker, RM': 'barker,rm',
#  'Barneby, R': 'barneby,r',
#  'Barneby, RC': 'barneby,rc',
#  'Barreto, ACC': 'barreto,acc',
#  'Barreto, D': 'barreto,d',
#  'Barreto, HLM': 'barreto,hlm',
#  'Barreto, KD': 'barreto,kd',
#  'Barreto, LAS': 'barreto,las',
#  'Barreto, LVF': 'barreto,lvf',
#  'Barreto, M': 'barreto,m',
#  'Barreto, MLA': 'barreto,mla',
#  'Barreto, R': 'barreto,r',
#  'Barreto, V': 'barreto,v',
#  'Barreto, VC': 'barreto,vc',
#  'Barros, A': 'barros,a',
#  'Barros, AG': 'barros,ag',
#  'Barros, AL': 'barros,al',
#  'Barros, BS': 'barros,bs',
#  'Barros, C': 'barros,c',
#  'Barros, CRMB': 'barros,crmb',
#  'Barros, F': 'barros,f',
#  'Barros, G': 'barros,g',
#  'Barros, GV': 'barros,gv',
#  'Barros, ICL': 'barros,icl',
#  'Barros, JS': 'barros,js',
#  'Barros, LAC': 'barros,lac',
#  'Barros, LES': 'barros,les',
#  'Barros, M': 'barros,m',
#  'Barros, MAG': 'barros,mag',
#  'Barros, MLS': 'barros,mls',
#  'Barros, NM': 'barros,nm',
#  'Barros, R': 'barros,r',
#  'Barros, S': 'barros,s',
#  'Barros, WD': 'barros,wd',
#  'Barroso, GM': 'barroso,gm',
#  'Barroso, JEM': 'barroso,jem',
#  'Barssukowa, A': 'barssukowa,a',
#  'Barter': 'barter',
#  'Barth, J': 'barth,j',
#  'Bartil, A': 'bartil,a',
#  'Bartlett, HH': 'bartlett,hh',
#  'Bartolomeu, ACD': 'bartolomeu,acd',
#  'Bartolomeu, J': 'bartolomeu,j',
#  'Bartolomeu, JG': 'bartolomeu,jg',
#  'Bartolotto, IM': 'bartolotto,im',
#  'Basso, F': 'basso,f',
#  'Basso, ME': 'basso,me',
#  'Bastianon, CVT': 'bastianon,cvt',
#  'Bastos (D. Preta), MAG': 'bastosdpreta,mag',
#  'Bastos Neto, OJ': 'bastosneto,oj',
#  'Bastos, AM': 'bastos,am',
#  'Bastos, BC': 'bastos,bc',
#  'Bastos, C': 'bastos,c',
#  'Bastos, CJP': 'bastos,cjp',
#  'Bastos, EB': 'bastos,eb',
#  'Bastos, EK': 'bastos,ek',
#  'Bastos, HM': 'bastos,hm',
#  'Bastos, JAA': 'bastos,jaa',
#  'Bastos, K': 'bastos,k',
#  'Bastos, M': 'bastos,m',
#  'Bastos, MFB': 'bastos,mfb',
#  'Bastos, N': 'bastos,n',
#  'Bastos, OJ': 'bastos,oj',
#  'Batalha, MA': 'batalha,ma',
#  'Batista, AC': 'batista,ac',
#  'Batista, AM': 'batista,am',
#  'Batista, CR': 'batista,cr',
#  'Batista, DF': 'batista,df',
#  'Batista, ER': 'batista,er',
#  'Batista, G': 'batista,g',
#  'Batista, GO': 'batista,go',
#  'Batista, GS': 'batista,gs',
#  'Batista, JAN': 'batista,jan',
#  'Batista, LBC': 'batista,lbc',
#  'Batista, MA': 'batista,ma',
#  'Batista, ML': 'batista,ml',
#  'Batista, MMF': 'batista,mmf',
#  'Batista, NTF': 'batista,ntf',
#  'Batista, R': 'batista,r',
#  'Batmanian, FJ': 'batmanian,fj',
#  'Batmanian, G': 'batmanian,g',
#  'Bauer, E': 'bauer,e',
#  'Bauerlen, W': 'bauerlen,w',
#  'Baumgarten, J': 'baumgarten,j',
#  'Baumgartz, JFA': 'baumgartz,jfa',
#  'Baumgratz, JFA': 'baumgratz,jfa',
#  'Baungarten, J': 'baungarten,j',
#  'Bausen, E': 'bausen,e',
#  'Bautista, HP': 'bautista,hp',
#  'Bazarian, SV': 'bazarian,sv',
#  'Baéz, P': 'baez,p',
#  'Bean, MF': 'bean,mf',
#  'Beatriz, MC': 'beatriz,mc',
#  'Beaupertuis': 'beaupertuis',
#  'Beccari, O': 'beccari,o',
#  'Beck, B': 'beck,b',
#  'Beck, G': 'beck,g',
#  'Beck, S': 'beck,s',
#  'Beck, StG': 'beck,stg',
#  'Becker, RM': 'becker,rm',
#  'Becker, VO': 'becker,vo',
#  'Bedim, A': 'bedim,a',
#  'Belchior, V': 'belchior,v',
#  'Belgrano, M': 'belgrano,m',
#  'Belinello, R': 'belinello,r',
#  'Belisario, M': 'belisario,m',
#  'Belizário, M': 'belisario,m',
#  'Belk, E': 'belk,e',
#  'Belko, T': 'belko,t',
#  'Bell, BG': 'bell,bg',
#  'Bell, RQ': 'bell,rq',
#  'Bello, JF': 'bello,jf',
#  'Bellolio, G': 'bellolio,g',
#  'Bellwinkel': 'bellwinkel',
#  'Belmok, LE': 'belmok,le',
#  'Beltrão, L': 'beltrao,l',
#  'Belém, PR': 'belem,pr',
#  'Belém, RP': 'belem,rp',
#  'Ben': 'ben',
#  'Bencke, CSC': 'bencke,csc',
#  'Benedet, AL': 'benedet,al',
#  'Benedete': 'benedete,al',
#  'Benedete, AL': 'benedete,al',
#  'Benedetti, FJ': 'benedetti,fj',
#  'Benedito, GSR': 'benedito,gsr',
#  'Benini, RM': 'benini,rm',
#  'Beninni, ST': 'beninni,st',
#  'Bennett, EM': 'bennett,em',
#  'Bennett, HR': 'bennett,hr',
#  'Benoliel, B': 'benoliel,b',
#  'Benson, D': 'benson,d',
#  'Benson, JL': 'benson,jl',
#  'Benson, WW': 'benson,ww',
#  'Bensusan, N': 'bensusan,nr',
#  'Bensusan, NR': 'bensusan,nr',
#  'Bentley, MS': 'bentley,ms',
#  'Bento, LSRN': 'bento,lsrn',
#  'Bento, MS': 'bento,ms',
#  'Benton, F': 'benton,fp',
#  'Benton, FP': 'benton,fp',
#  'Benício': 'benicio',
#  'Berg, CC': 'berg,cc',
#  'Bergalli': 'bergalli',
#  'Bergamini, LL': 'bergamini,ll',
#  'Berger, A': 'berger,a',
#  'Bergo, NM': 'bergo,nm',
#  'Bergossi, AM': 'bergossi,am',
#  'Bernabé, MJC': 'bernabe,mjc',
#  'Bernacci, LC': 'bernacci,lc',
#  'Bernacci, M': 'bernacci,m',
#  'Bernadete': 'bernadete',
#  'Bernadino, J': 'bernadino,j',
#  'Bernal, RA': 'bernal,ra',
#  'Bernardes, C': 'bernardes,c',
#  'Bernardes, CB': 'bernardes,cb',
#  'Bernardes, PHN': 'bernardes,phn',
#  'Bernardino, J': 'bernardino,j',
#  'Bernardo, CM': 'bernardo,cm',
#  'Bernasol, WP': 'bernasol,wp',
#  'Bernd, RB': 'bernd,rb',
#  'Bernhardt, R': 'bernhardt,r',
#  'Bertanha, WFF': 'bertanha,wff',
#  'Bertani, DF': 'bertani,df',
#  'Bertazzoni, EC': 'bertazzoni,ec',
#  'Berto, ACV': 'berto,acv',
#  'Bertocini, AP': 'bertocini,ap',
#  'Bertolda, J': 'bertoldo,j',
#  'Bertoldo, J': 'bertoldo,j',
#  'Bertoli, AG': 'bertoli,ag',
#  'Bertoncini, AP': 'bertoncini,ap',
#  'Bertoni, JEA': 'bertoni,jea',
#  'Berçot, ACS': 'bercot,acs',
#  'Berçot, C': 'bercot,c',
#  'Bessa, MA': 'bessa,ma',
#  'Bessa, RS': 'bessa,rs',
#  'Bessler, H': 'bessler,h',
#  'Betche, E': 'betche,e',
#  'Beusekom, V': 'beusekom,v',
#  'Beyer, C': 'beyer,c',
#  'Bezerra, A': 'bezerra,a',
#  'Bezerra, CLF': 'bezerra,clf',
#  'Bezerra, KMG': 'bezerra,kmg',
#  'Bezerra, LFD': 'bezerra,lfd',
#  'Bezerra, M': 'bezerra,m',
#  'Bezerra, MG': 'bezerra,mg',
#  'Bezerra, P': 'bezerra,p',
#  'Bezerra, REP': 'bezerra,rep',
#  'Bhagirathi, S': 'bhagirathi,s',
#  'Biagi, F': 'biagi,f',
#  'Bianca, AM': 'bianca,am',
#  'Bianchetti, L': 'bianchetti,l',
#  'Bianchetti, LB': 'bianchetti,lb',
#  'Bianchi, C': 'bianchi,c',
#  'Bianchini, E': 'bianchini,e',
#  'Bianchini, RS': 'bianchini,rs',
#  'Biavati, GM': 'biavati,gm',
#  'Bicalho, H': 'bicalho,h',
#  'Bicudo, LRH': 'bicudo,lrh',
#  'Bicudo, PL': 'bicudo,pl',
#  'Bid': 'bid',
#  'Bidá, A': 'bida,a',
#  'Biernaski': 'biernaski',
#  'Biese, W': 'biese,w',
#  'Bieski, I': 'bieski,i',
#  'Biggs, N': 'biggs,n',
#  'Bijos, NR': 'bijos,nr',
#  'Bilby, R': 'bilby,r',
#  'Bisang, I': 'bisang,i',
#  'Bishop, LE': 'bishop,le',
#  'Bishop, W': 'bishop,w',
#  'Bisset': 'bisset',
#  'Bittencourt, PV': 'bittencourt,pv',
#  'Bittencourt, SET': 'bittencourt,set',
#  'Bizerril, MX': 'bizerril,mx',
#  'Black': 'black,ga',
#  'Black, CA': 'black,ga',
#  'Black, G': 'black,ga',
#  'Black, GA': 'black,ga',
#  'Black, JM': 'black,jm',
#  'Blackmore, J': 'blackmore,j',
#  'Blake, D': 'blake,d',
#  'Blake, ER': 'blake,er',
#  'Blakely, WF': 'blakely,wf',
#  'Blanchet': 'blanchet',
#  'Blanco, S': 'blanco,s',
#  'Blaxell, D': 'blaxell,d',
#  'Block, D': 'block,d',
#  'Blocki': 'blocki',
#  'Blomquist, HL': 'blomquist,hl',
#  'Blotz': 'blotz',
#  'Blum, KE': 'blum,ke',
#  'Boabaid, LF': 'boabaid,lf',
#  'Boaventura, M': 'boaventura,m',
#  'Bocenstain, SS': 'bocenstain,ss',
#  'Bockermann, W': 'bockermann,w',
#  'Bodens, FWP': 'bodens,fwp',
#  'Boeke, J': 'boeke,j',
#  'Boelter, CR': 'boelter,cr',
#  'Boff, SV': 'boff,sv',
#  'Bogner, J': 'bogner,j',
#  'Boguado, MMF': 'boguado,mmf',
#  'Bohlinger, M': 'bohlinger,m',
#  'Bohren, A': 'bohren,a',
#  'Bohrer, P': 'bohrer,p',
#  'Bohs, L': 'bohs,l',
#  'Boiteux, MS': 'boiteux,ms',
#  'Boldingh': 'boldingh',
#  'Boldissera, Z': 'boldissera,z',
#  'Bolten, A': 'bolten,a',
#  'Bolton': 'bolton',
#  'Bomfim, NN': 'bomfim,nn',
#  'Bomley, GL': 'bromley,gl',
#  'Bommer': 'bommer',
#  'Bommer, DFR': 'bommer,dfr',
#  'Bommer, FR': 'bommer,fr',
#  'Bon, Fr HF': 'bon,frhf',
#  'Bonaldo, D': 'bonaldo,d',
#  'Bonasora, MG': 'bonasora,mg',
#  'Bonatto, F': 'bonatto,f',
#  'Bondar, G': 'bondar,g',
#  'Bonilia, M': 'bonilia,m',
#  'Bonniel, G': 'bonniel,g',
#  'Bonomo': 'bonomo',
#  'Bonomo, VS': 'bonomo,vs',
#  'Bonotto, I': 'bonotto,i',
#  'Boom, B': 'boom,bm',
#  'Boom, BM': 'boom,bm',
#  'Boone, W': 'boone,w',
#  'Boorman, JL': 'boorman,jl',
#  'Boos, J': 'boos,j',
#  'Boquadi, MMF': 'boquadi,mmf',
#  'Borba, EL': 'borba,el',
#  'Borba, JAF': 'borba,jaf',
#  'Borba, MF': 'borba,mf',
#  'Borborema, PA': 'borborema,pa',
#  'Borchert, MI': 'borchert,mi',
#  'Bordin, J': 'bordin,j',
#  'Bordini, MCP': 'bordini,mcp',
#  'Bordo, A': 'bordo,a',
#  'Borenstaim, SS': 'borenstaim,ss',
#  'Borenstain, SS': 'borenstain,ss',
#  'Borgato, D': 'borgato,d',
#  'Borgato, DF': 'borgatto,df',
#  'Borgatto, DF': 'borgatto,df',
#  'Borgerth, A': 'borgerth,a',
#  'Borges, AV': 'borges,av',
#  'Borges, CMO': 'borges,cmo',
#  'Borges, D': 'borges,d',
#  'Borges, DN': 'borges,dn',
#  'Borges, EC': 'borges,ec',
#  'Borges, HBN': 'borges,hbn',
#  'Borges, J': 'borges,jwm',
#  'Borges, JG': 'borges,jg',
#  'Borges, JW': 'borges,jwm',
#  'Borges, JWM': 'borges,jwm',
#  'Borges, KP': 'borges,kp',
#  'Borges, L': 'borges,l',
#  'Borges, LM': 'borges,lm',
#  'Borges, PL': 'borges,pl',
#  'Borges, R': 'borges,rax',
#  'Borges, RAX': 'borges,rax',
#  'Borges, RF': 'borges,rf',
#  'Borges, SH': 'borges,sh',
#  'Borges, SM': 'borges,sm',
#  'Borges, SR': 'borges,sr',
#  'Borges, V': 'borges,v',
#  'Borghetti, F': 'borghetti,f',
#  'Borghi, F': 'borghi,f',
#  'Borgo, M': 'borgo,m',
#  'Borin, ALDC': 'borin,aldc',
#  'Boring, LKK': 'boring,lkk',
#  'Born, R': 'born,r',
#  'Borsato, A': 'borsato,a',
#  'Borsini, OH': 'borsini,oh',
#  'Bortoletto, CA': 'bortoletto,ca',
#  'Bortolotto, IM': 'bortolotto,im',
#  'Bortoluzzi, RLC': 'bortoluzzi,rlc',
#  'Bosman, M': 'bosman,m',
#  'Bosquetti, LB': 'bosquetti,lb',
#  'Botelho, MB': 'botelho,mb',
#  'Botinhão, J': 'botinhao,j',
#  'Bouchardet, DA': 'bouchardet,da',
#  'Boudet, HQ': 'boudet,hq',
#  'Bourell, M': 'bourell,m',
#  'Bovey, R': 'bovey,r',
#  'Bovini, M': 'bovini,m',
#  'Bovini, MG': 'bovini,mg',
#  'Boyan, R': 'boyan,r',
#  'Brade': 'brade,ac',
#  'Brade, AC': 'brade,ac',
#  'Braga, A': 'braga,a',
#  'Braga, AGB': 'braga,agb',
#  'Braga, ALV': 'braga,alv',
#  'Braga, EP': 'braga,ep',
#  'Braga, JMA': 'braga,jma',
#  'Braga, JP': 'braga,jp',
#  'Braga, L': 'braga,l',
#  'Braga, MNM': 'braga,mnm',
#  'Braga, P': 'braga,p',
#  'Braga, PIS': 'braga,pis',
#  'Braga, PTS': 'braga,pts',
#  'Braga, R': 'braga,r',
#  'Braga, RDV': 'braga,rdv',
#  'Brahim, KA': 'brahim,ka',
#  'Brako, L': 'brako,l',
#  'Branco, L': 'branco,l',
#  'Branco, R': 'branco,r',
#  'Brand, GD': 'brand,gd',
#  'Brandão, D': 'brandao,d',
#  'Brandão, JLA': 'brandao,jla',
#  'Brandão, L': 'brandao,l',
#  'Brandão, M': 'brandao,m',
#  'Brandão, MMV': 'brandao,mmv',
#  'Brandão, R': 'brandao,r',
#  'Brandão, RA': 'brandao,ra',
#  'Brant, HSC': 'brant,hsc',
#  'Brasileiro, AC': 'brasileiro,ac',
#  'Brasileiro, SS': 'brasileiro,ss',
#  'Brass, LJ': 'brass,lj',
#  'Brasília, EJB': 'brasilia,ejb',
#  'Brasília, TCU': 'brasilia,tcu',
#  'Braun, KP': 'braun,kp',
#  'Braun, S': 'braun,s',
#  'Braz, V': 'braz,v',
#  'Brazão, JEM': 'brazao,jem',
#  'Brazão, U': 'brazao,u',
#  'Breakwell, E': 'breakwell,e',
#  'Bredenkamp, CL': 'bredenkamp,cl',
#  'Breder, J': 'breder,j',
#  'Bredt, A': 'bredt,a',
#  'Breedlove, DE': 'breedlove,de',
#  'Breier, TB': 'breier,tb',
#  'Breitenbach, J': 'breitenbach,j',
#  'Brenan, JPM': 'brenan,jpm',
#  'Brener Roberto': 'brenerroberto',
#  'Brenes, AM': 'brenes,am',
#  'Bresolin': 'bresolin',
#  'Bresolin, A': 'bresolin,a',
#  'Breteler, FJ': 'breteler,fj',
#  'Breteler, FJ14': 'breteler,fj',
#  'Breyer, LM': 'breyer,lm',
#  'Bridgewater, S': 'bridgewater,s',
#  'Brigatto, UA': 'brigatto,ua',
#  'Brighton, CA': 'brighton,ca',
#  'Brilhante, M': 'brilhante,m',
#  'Brinda, J': 'brinda,j',
#  'Bringel, JBA': 'bringel,jba',
#  'Brites, RM': 'brites,rm',
#  'Britez, RM': 'britez,rm',
#  'Brito, AAR': 'brito,aar',
#  'Brito, ACS': 'brito,acs',
#  'Brito, ALTV': 'brito,altv',
#  'Brito, ALVT': 'brito,alvt',
#  'Brito, AT': 'brito,at',
#  'Brito, DS': 'brito,ds',
#  'Brito, ES': 'brito,es',
#  'Brito, HS': 'brito,hs',
#  'Brito, IC': 'britto,ic',
#  'Brito, JAC': 'brito,jac',
#  'Brito, JC': 'brito,jc',
#  'Brito, JM': 'brito,jm',
#  'Brito, KB': 'brito,kb',
#  'Brito, LEB': 'brito,leb',
#  'Brito, M': 'brito,m',
#  'Brito, MCC': 'brito,mcc',
#  'Brito, MH': 'brito,mh',
#  'Brito, P': 'brito,p',
#  'Brito, RM': 'brito,rm',
#  'Brito, SM': 'brito,sm',
#  'Brito, TH': 'brito,th',
#  'Britto, G': 'britto,g',
#  'Britto, IC': 'britto,ic',
#  'Britto, KB': 'britto,kb',
#  'Britto, R': 'britto,r',
#  'Britto, RC': 'britto,rc',
#  'Britton, EG': 'britton,eg',
#  'Britton, NL': 'britton,nl',
#  'Brochado, AL': 'brochado,al',
#  'Brochado, TS': 'brochado,ts',
#  'Brom, ACM': 'brom,acm',
#  'Bromley, G': 'bromley,gl',
#  'Bromley, GL': 'bromley,gl',
#  'Brooker, MIH': 'brooker,mih',
#  'Brotherus, VF': 'brotherus,vf',
#  'Brotto, ML': 'brotto,ml',
#  'Brown, FH': 'brown,fh',
#  'Brown, HH': 'brown,hh',
#  'Brown, MT': 'brown,mt',
#  'Browne, GW': 'browne,gw',
#  'Bruera, J': 'bruera,j',
#  'Brugger, M': 'brugger,m',
#  'Brugger, MC': 'brugger,mc',
#  'Bruhl, J': 'bruhl,j',
#  'Brujjer, M': 'brujjer,m',
#  'Brumbach, WC': 'brumbach,wc',
#  'Brummitt, NA': 'brummitt,na',
#  'Bruno': 'bruno',
#  'Brügger, M': 'brugger,m',
#  'Brügger, MC': 'brugger,mc',
#  'Bucci, F': 'bucci,ffb',
#  'Bucci, FFB': 'bucci,ffb',
#  'Bucher, JP': 'bucher,jp',
#  'Buck, WR': 'buck,wr',
#  'Buddén, I': 'budden,i',
#  'Budziak, C': 'budziak,c',
#  'Bueno': 'bueno',
#  'Bueno, B': 'bueno,b',
#  'Bueno, DF': 'bueno,df',
#  'Bueno, ML': 'bueno,ml',
#  'Bueno, N': 'bueno,n',
#  'Bueno, NC': 'bueno,nc',
#  'Bueno, NRC': 'bueno,nrc',
#  ...}

# %%
len(G['silva,t'])
# Out:
# 2

# %%
names = list(G.nodes())
dfl.get_close_matches('proenca', names)
# Out:
# ['proenca,sl', 'proenca,ceb', 'rocha']

# %%
l1 = ['a','b','c','d']
l2 = ['a','b','c','d', 'e']

def similarity(l1,l2):
    if len(l1)>len(l2):
        mainList, testList = l1,l2
    else: 
        mainList, testList = l2,l1
    
    score = sum( 1 if i in mainList else 0 for i in testList )/len(testList)
    
    return score

def nodesSimilarity( G, node1, node2 ):
    return similarity(list(G[node1]), list(G[node2]))

# %%
sorted( nx.degree(G).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('proenca,ceb', 249),
#  ('ratter,ja', 131),
#  ('faria,jeq', 128),
#  ('munhoz,cbr', 125),
#  ('carvalho,am', 107),
#  ('silva,ma', 106),
#  ('oliveira,rc', 98),
#  ('souza,vc', 96),
#  ('mendonca,rc', 95),
#  ('mendes,vc', 92),
#  ('harley,rm', 92),
#  ('walter,bmt', 92),
#  ('franca,f', 86),
#  ('melo,e', 77),
#  ('cardoso,e', 77),
#  ('silva,gp', 74),
#  ('martins,rc', 66),
#  ('carvalhosilva,m', 64),
#  ('santana,sc', 63),
#  ('jardim,jg', 63),
#  ('fonsecafilho,j', 62),
#  ('pirani,jr', 62),
#  ('hatschbach,g', 59),
#  ('bridgewater,s', 59),
#  ('silvajunior,mc', 59),
#  ('camara,peas', 58),
#  ('cordeiro,i', 54),
#  ('shevock,jr', 54),
#  ('filgueiras,ts', 53),
#  ('zanatta,mrv', 53),
#  ('souza,r', 52),
#  ('irwin,hs', 51),
#  ('oliveira,m', 51),
#  ('mellosilva,r', 49),
#  ('silva,jm', 49),
#  ('oliveira,nr', 48),
#  ('forzza,rc', 48),
#  ('souza,jp', 47),
#  ('silva,js', 46),
#  ('heringer,ep', 46),
#  ('santos,rr', 46),
#  ('alvarenga,d', 46),
#  ('cavalcanti,tb', 46),
#  ('francener,a', 45),
#  ('santos,ts', 44),
#  ('novelino,rf', 44),
#  ('ivanauskas,nm', 44),
#  ('ribeiro,jf', 43),
#  ('goncalves,eg', 43),
#  ('amorim,am', 43),
#  ('giulietti,aml', 42),
#  ('prance,gt', 41),
#  ('semir,j', 41),
#  ('caires,cs', 41),
#  ('fonseca,ml', 41),
#  ('assis,mc', 41),
#  ('soaressilva,lh', 40),
#  ('farias,r', 40),
#  ('nakajima,jn', 40),
#  ('romero,r', 40),
#  ('giulietti,am', 40),
#  ('simon,mf', 39),
#  ('fagg,cw', 39),
#  ('mazinecapelo,ff', 39),
#  ('pires,jm', 38),
#  ('eiten,g', 37),
#  ('queiroz,lp', 37),
#  ('pereira,jb', 36),
#  ('amaral,ag', 36),
#  ('silva,fc', 35),
#  ('oliveira,fca', 34),
#  ('villarroel,d', 34),
#  ('meneguzzo,tec', 34),
#  ('silva,pen', 33),
#  ('rodrigues,rr', 33),
#  ('silva,rm', 33),
#  ('pott,a', 32),
#  ('felfili,jm', 32),
#  ('santos,jb', 32),
#  ('thomas,ww', 32),
#  ('carvalho,ja', 32),
#  ('amorim,a', 32),
#  ('hind,djn', 32),
#  ('souza,mgm', 32),
#  ('soares,aer', 32),
#  ('paixao,jl', 32),
#  ('ramos,jf', 31),
#  ('lima,jcm', 31),
#  ('furlan,a', 31),
#  ('ribas,os', 31),
#  ('santos,aa', 31),
#  ('romao,go', 31),
#  ('rosa,po', 31),
#  ('reis,pa', 31),
#  ('santana,s', 31),
#  ('amaral,il', 30),
#  ('fonseca,j', 30),
#  ('milhomens,lc', 30),
#  ('silva,bm', 30),
#  ('haidar,rf', 30),
#  ('kirkbridejunior,jh', 29),
#  ('barros,mag', 29),
#  ('pereira,bas', 29),
#  ('scalon,vr', 29),
#  ('lucas,ej', 29),
#  ('paula,je', 28),
#  ('fiaschi,p', 28),
#  ('amorim,prf', 28),
#  ('barroso,gm', 27),
#  ('sakuragui,cm', 27),
#  ('klein,vlg', 27),
#  ('hage,jl', 27),
#  ('dias,eba', 27),
#  ('campos,lzo', 27),
#  ('fontana,ap', 27),
#  ('onishi,e', 26),
#  ('menezes,nl', 26),
#  ('mecenas,vv', 26),
#  ('teles,am', 26),
#  ('assuncao,pacl', 26),
#  ('ribeiro,aro', 26),
#  ('paixao,j', 26),
#  ('flores,tb', 26),
#  ('ramos,j', 25),
#  ('mori,sa', 25),
#  ('kirizawa,m', 25),
#  ('oliveira,rp', 25),
#  ('bringel,jba', 25),
#  ('moreira,ga', 25),
#  ('silva,lam', 24),
#  ('silva,rr', 24),
#  ('leitaofilho,hf', 24),
#  ('barbosa,e', 24),
#  ('santos,e', 24),
#  ('stannard,b', 24),
#  ('chacon,rg', 24),
#  ('gomes,bm', 23),
#  ('fonseca,sg', 23),
#  ('fonseca,sf', 23),
#  ('zappi,dc', 23),
#  ('sano,pt', 23),
#  ('sampaio,ab', 23),
#  ('jesus,fpr', 23),
#  ('marquete,r', 23),
#  ('pacheco,ra', 23),
#  ('kollmann,l', 23),
#  ('plowman,tc', 22),
#  ('anderson,wr', 22),
#  ('black,ga', 22),
#  ('maguire,b', 22),
#  ('cervi,ac', 22),
#  ('francisco,em', 22),
#  ('lima,j', 22),
#  ('cordovil,sp', 22),
#  ('silva,mg', 22),
#  ('chaves,e', 22),
#  ('costa,ir', 22),
#  ('gama,r', 22),
#  ('costa,dp', 22),
#  ('amaral,ac', 22),
#  ('cardoso,d', 22),
#  ('forero,e', 21),
#  ('kawasaki,ml', 21),
#  ('rossi,l', 21),
#  ('silva,jc', 21),
#  ('kinoshita,ls', 21),
#  ('hensold,n', 21),
#  ('shepherd,gj', 21),
#  ('sobral,m', 21),
#  ('silva,am', 21),
#  ('delprete,pg', 21),
#  ('pinheiro,eml', 21),
#  ('carvalhosobrinho,jg', 21),
#  ('mello,trb', 21),
#  ('amaral,jp', 21),
#  ('gomes,sm', 20),
#  ('philcox,d', 20),
#  ('ramos,ae', 20),
#  ('maas,pjm', 20),
#  ('pott,vj', 20),
#  ('schinini,a', 20),
#  ('rodrigues,n', 20),
#  ('barros,m', 20),
#  ('harley,r', 20),
#  ('landim,mf', 20),
#  ('lorenzi,h', 20),
#  ('correia,c', 20),
#  ('santos,er', 20),
#  ('brito,hs', 20),
#  ('cordeiro,j', 20),
#  ('souza,er', 20),
#  ('silva,csp', 20),
#  ('silva,as', 20),
#  ('chaves,da', 20),
#  ('cota,mrc', 20),
#  ('nobre,ph', 20),
#  ('concha,c', 20),
#  ('projetobiodiversidadebp', 20),
#  ('silva,nt', 19),
#  ('martinelli,g', 19),
#  ('dias,bj', 19),
#  ('silva,ap', 19),
#  ('duval,fg', 19),
#  ('pereira,ec', 19),
#  ('lima,v', 19),
#  ('fankdecarvalho,sm', 19),
#  ('alves,j', 19),
#  ('castro,rm', 19),
#  ('salimena,frg', 19),
#  ('andrade,mc', 19),
#  ('maciel,jr', 19),
#  ('belinello,r', 19),
#  ('sartin,rd', 19),
#  ('castro,ra', 18),
#  ('monteiro,op', 18),
#  ('stannard,bl', 18),
#  ('rocha,dms', 18),
#  ('taxonomyclassofuniversidadedebrasilia', 18),
#  ('araujo,d', 18),
#  ('kameyama,c', 18),
#  ('silva,jcs', 18),
#  ('lombardi,ja', 18),
#  ('silva,mm', 18),
#  ('miranda,sc', 18),
#  ('mendes,s', 18),
#  ('sousa,rv', 18),
#  ('moura,co', 18),
#  ('soderstrom,tr', 17),
#  ('rezende,av', 17),
#  ('silva,sr', 17),
#  ('rosa,na', 17),
#  ('duarte,ar', 17),
#  ('nobrega,mg', 17),
#  ('alves,m', 17),
#  ('ganev,w', 17),
#  ('silva,cf', 17),
#  ('bianchetti,lb', 17),
#  ('amorim,ama', 17),
#  ('romaniucneto,s', 17),
#  ('vieira,rf', 17),
#  ('hattori,eko', 17),
#  ('mendes,mra', 17),
#  ('santos,jr', 17),
#  ('udulutsch,rg', 17),
#  ('lewis,gp', 17),
#  ('soto,d', 17),
#  ('coveny,rg', 17),
#  ('arantes,aa', 17),
#  ('nascimento,ea', 16),
#  ('silva,ja', 16),
#  ('rodrigues,wa', 16),
#  ('duarte,ap', 16),
#  ('araujo,gm', 16),
#  ('hopkins,mjg', 16),
#  ('brade,ac', 16),
#  ('bucci,ffb', 16),
#  ('rocha,m', 16),
#  ('krapovickas,a', 16),
#  ('fernandes,a', 16),
#  ('mota,cda', 16),
#  ('santos,eb', 16),
#  ('wanderley,mgl', 16),
#  ('dias,tab', 16),
#  ('prado,j', 16),
#  ('carvalho,ps', 16),
#  ('vale,gd', 16),
#  ('staggemeier,vg', 16),
#  ('bausen,e', 16),
#  ('paiva,vf', 16),
#  ('amorim,eh', 16),
#  ('souza,enf', 16),
#  ('leite,krb', 16),
#  ('tsuji,r', 16),
#  ('sampaio,d', 16),
#  ('miranda,am', 16),
#  ('moura,tm', 16),
#  ('oliveira,rs', 15),
#  ('brito,ds', 15),
#  ('ferreira,a', 15),
#  ('belem,rp', 15),
#  ('richards,pw', 15),
#  ('pereiraneto,m', 15),
#  ('smith,gl', 15),
#  ('ferreira,cac', 15),
#  ('giulietti,n', 15),
#  ('miyagi,ph', 15),
#  ('machado,mg', 15),
#  ('ramalho,cl', 15),
#  ('alvarenga,a', 15),
#  ('nunes,ts', 15),
#  ('yano,o', 15),
#  ('xavier,s', 15),
#  ('volpi,rl', 15),
#  ('rivera,vl', 15),
#  ('melo,ms', 15),
#  ('damascenojunior,ga', 15),
#  ('viana,pl', 15),
#  ('gomes,lcj', 15),
#  ('chaves,be', 15),
#  ('martins,ds', 15),
#  ('campos,or', 15),
#  ('meninineto,l', 15),
#  ('iglesias,jov', 15),
#  ('eiten,lt', 14),
#  ('pereira,e', 14),
#  ('azevedo,mlm', 14),
#  ('lughadha,en', 14),
#  ('souza,mad', 14),
#  ('fonseca,lm', 14),
#  ('ribeiro,f', 14),
#  ('castro,aj', 14),
#  ('ribeiro,dg', 14),
#  ('santos,fam', 14),
#  ('lima,as', 14),
#  ('silva,m', 14),
#  ('simao,r', 14),
#  ('faria,ca', 14),
#  ('bezerra,kmg', 14),
#  ('turmadebotanicadecampo', 14),
#  ('tamashiro,jy', 14),
#  ('elias,si', 14),
#  ('silveira,am', 14),
#  ('guarino,esg', 14),
#  ('castro,nm', 14),
#  ('fontes,cg', 14),
#  ('junqueira,di', 14),
#  ('carvalho,a', 14),
#  ('moreira,tb', 14),
#  ('pastore,ja', 14),
#  ('wilson,kl', 14),
#  ('mamede,mch', 14),
#  ('silva,mc', 14),
#  ('brummitt,na', 14),
#  ('sousa,mws', 14),
#  ('sucre,d', 13),
#  ('lima,hc', 13),
#  ('viollati,lg', 13),
#  ('wurdack,jj', 13),
#  ('coradin,lc', 13),
#  ('kummrow,r', 13),
#  ('davidse,g', 13),
#  ('paiva,jga', 13),
#  ('mesquita,mr', 13),
#  ('ribeiro,jels', 13),
#  ('rios,l', 13),
#  ('moraes,plr', 13),
#  ('mantovani,w', 13),
#  ('barros,f', 13),
#  ('silva,s', 13),
#  ('xavier,scs', 13),
#  ('pinto,jrr', 13),
#  ('alves,mv', 13),
#  ('santos,h', 13),
#  ('eugenio,cuo', 13),
#  ('alkimim,w', 13),
#  ('gomes,l', 13),
#  ('conceicao,tc', 13),
#  ('souza,fm', 13),
#  ('stehmann,jr', 13),
#  ('assis,lcs', 13),
#  ('silva,agd', 13),
#  ('caliari,cp', 13),
#  ('gonzaga,rmo', 13),
#  ('santana,sh', 13),
#  ('landim,m', 13),
#  ('santos,mf', 13),
#  ('hall,cf', 13),
#  ('barboza,e', 13),
#  ('nogales,t', 12),
#  ('haridasan,m', 12),
#  ('cid,ca', 12),
#  ('lima,a', 12),
#  ('lopes,ec', 12),
#  ('machado,jwb', 12),
#  ('killip,ep', 12),
#  ('carauta,jpp', 12),
#  ('werneck,wl', 12),
#  ('leite,fq', 12),
#  ('medeiros,mb', 12),
#  ('arbo,mm', 12),
#  ('jardim,j', 12),
#  ('miranda,j', 12),
#  ('simpsonjunior,pl', 12),
#  ('potzernheim,ml', 12),
#  ('filho,jf', 12),
#  ('macedo,m', 12),
#  ('paixao,jf', 12),
#  ('silva,asl', 12),
#  ('pipoly,jj', 12),
#  ('roque,n', 12),
#  ('queiroz,rf', 12),
#  ('pastore,jfb', 12),
#  ('filgueiras,ad', 12),
#  ('pereira,ga', 12),
#  ('silva,af', 12),
#  ('matos,mq', 12),
#  ('moreira,alc', 12),
#  ('demuner,v', 12),
#  ('sevilha,ac', 12),
#  ('araujo,ao', 12),
#  ('kuhlmann,m', 12),
#  ('soares', 12),
#  ('neiva,caf', 12),
#  ('baitello,jb', 12),
#  ('niclughada,em', 12),
#  ('araujo,je', 12),
#  ('sasaki,d', 12),
#  ('perdiz,r', 12),
#  ('silva,jb', 12),
#  ('coveny,r', 12),
#  ('carvalho,amv', 12),
#  ('dias,jb', 12),
#  ('silva,dc', 12),
#  ('stieber,m', 11),
#  ('almeida,sp', 11),
#  ('steward,wc', 11),
#  ('westra,lyth', 11),
#  ('steyermark,ja', 11),
#  ('maguire,ck', 11),
#  ('silva,n', 11),
#  ('cardoso,es', 11),
#  ('bianchetti,l', 11),
#  ('harris,sa', 11),
#  ('hatschbach,m', 11),
#  ('guimaraes,pjf', 11),
#  ('guedes,j', 11),
#  ('cruz,jm', 11),
#  ('oliveira,n', 11),
#  ('landrum,lr', 11),
#  ('heringer,ae', 11),
#  ('bensusan,nr', 11),
#  ('passos,fb', 11),
#  ('alvim,mb', 11),
#  ('pereira,ffo', 11),
#  ('poliquesi,cb', 11),
#  ('jung,sl', 11),
#  ('tavares,g', 11),
#  ('santos,hgp', 11),
#  ('shepherd,g', 11),
#  ('campos,mbs', 11),
#  ('rosario,cs', 11),
#  ('silva,a', 11),
#  ('anapaula', 11),
#  ('costa,jm', 11),
#  ('sousa,r', 11),
#  ('damasceno,ga', 11),
#  ('nogueira,lmg', 11),
#  ('wood,jri', 11),
#  ('laine,u', 11),
#  ('alava,r', 11),
#  ('solorzano,a', 11),
#  ('giotto,ac', 11),
#  ('silva,mr', 11),
#  ('peralta,df', 11),
#  ('verola,cf', 11),
#  ('oliveira,acp', 11),
#  ('guedes,ml', 11),
#  ('lopes,m', 11),
#  ('santos,apb', 11),
#  ('pesqueira,us', 11),
#  ('aguiar,aca', 11),
#  ('lourenco,jlm', 11),
#  ('versiane,afa', 11),
#  ('bernardes,phn', 11),
#  ('queiroz,mvd', 11),
#  ('silva,dp', 11),
#  ('hawthorne,w', 11),
#  ('cardoso,agt', 11),
#  ('chiea,sc', 10),
#  ('lima,da', 10),
#  ('coelho,lf', 10),
#  ('vital,dm', 10),
#  ('lindeman,jc', 10),
#  ('splett,s', 10),
#  ('lima,vp', 10),
#  ('macleish,nff', 10),
#  ('gomesjunior,jc', 10),
#  ('jacques,el', 10),
#  ('miranda,zjg', 10),
#  ('noletto,lg', 10),
#  ('noblick,lr', 10),
#  ('vieira,s', 10),
#  ('leoni,ls', 10),
#  ('ferreira,j', 10),
#  ('brito,jm', 10),
#  ('ribeiro,aj', 10),
#  ('libano,am', 10),
#  ('yamamoto,k', 10),
#  ('scariot,ao', 10),
#  ('rodrigues,as', 10),
#  ('tavares,as', 10),
#  ('melo,mrf', 10),
#  ('carvalho,vm', 10),
#  ('costa,mas', 10),
#  ('silva,vs', 10),
#  ('amaral,mce', 10),
#  ('nascimento,ae', 10),
#  ('capellarijunior,l', 10),
#  ('forster,w', 10),
#  ('vanni,r', 10),
#  ('rezende,jm', 10),
#  ('correa,acg', 10),
#  ('bosquetti,lb', 10),
#  ('saavedra,mm', 10),
#  ('moura,c', 10),
#  ('ramos,dm', 10),
#  ('rando,jg', 10),
#  ('pereirasilva,g', 10),
#  ('azevedo,inc', 10),
#  ('vervloet,rr', 10),
#  ('faria,ala', 10),
#  ('gracianoribeiro,d', 10),
#  ('borges,rax', 10),
#  ('lima,h', 10),
#  ('siqueira,gs', 10),
#  ('barbosa,nf', 10),
#  ('silva,rh', 10),
#  ('bueno,ml', 10),
#  ('cruz,gaf', 10),
#  ('izetti,c', 10),
#  ('oku,w', 10),
#  ('sonsin,j', 10),
#  ('nelson,bw', 9),
#  ('davis,ph', 9),
#  ('hill,sr', 9),
#  ('mendonca,r', 9),
#  ('souza,ml', 9),
#  ('lima,rp', 9),
#  ('mota,cd', 9),
#  ('tressens,s', 9),
#  ('santos,ml', 9),
#  ('barboza,ma', 9),
#  ('nunes,jvc', 9),
#  ('fernandes,jb', 9),
#  ('matos,j', 9),
#  ('miotto,sts', 9),
#  ('santos,gb', 9),
#  ('cardoso,cfr', 9),
#  ('bucher,jp', 9),
#  ('fonseca', 9),
#  ('mori,s', 9),
#  ('cornelio,in', 9),
#  ('oliveira,a', 9),
#  ('kubitzki,k', 9),
#  ('lima,jf', 9),
#  ('monteiro,jrb', 9),
#  ('vinha,sg', 9),
#  ('delgado,sm', 9),
#  ('martins,fr', 9),
#  ('nascimento,jr', 9),
#  ('vieira,jga', 9),
#  ('custodiofilho,a', 9),
#  ('kallunki,j', 9),
#  ('silva,e', 9),
#  ('passon,l', 9),
#  ('rosa,loc', 9),
#  ('felippe,gm', 9),
#  ('pennington,rt', 9),
#  ('sales,m', 9),
#  ('chukr,ns', 9),
#  ('zanin,a', 9),
#  ('souza,lf', 9),
#  ('krieger,l', 9),
#  ('turmadevegetacaodocerrado', 9),
#  ('jesus,ng', 9),
#  ('cordovil,s', 9),
#  ('stein,mg', 9),
#  ('guimaraes,ll', 9),
#  ('arruda,r', 9),
#  ('fernandes,jh', 9),
#  ('silva,lh', 9),
#  ('arbocz,gf', 9),
#  ('pereira,im', 9),
#  ('sugiyama,m', 9),
#  ('santos,b', 9),
#  ('ibrahim,m', 9),
#  ('paulasouza,j', 9),
#  ('longhi,hm', 9),
#  ('marunak,v', 9),
#  ('silva,ml', 9),
#  ('sajo,mg', 9),
#  ('fraga,cn', 9),
#  ('mota,t', 9),
#  ('wagner,hl', 9),
#  ('soares,far', 9),
#  ('matos,f', 9),
#  ('urbanetz,c', 9),
#  ('rocha,f', 9),
#  ('nakagomi,my', 9),
#  ('felix,lp', 9),
#  ('polisel,rt', 9),
#  ('mota,nfo', 9),
#  ('sousa,g', 9),
#  ('bovini,mg', 9),
#  ('catharino,elm', 9),
#  ('teixeirajunior,aq', 9),
#  ('juchum,f', 9),
#  ('bicudo,lrh', 9),
#  ('reis,gc', 9),
#  ('bijos,nr', 9),
#  ('aguiar,ot', 9),
#  ('machado,aimr', 9),
#  ('silva,mj', 9),
#  ('alves,fm', 9),
#  ('bourell,m', 9),
#  ('mundim,jv', 9),
#  ('antunes,llc', 9),
#  ('oliveira,j', 8),
#  ('silva,mn', 8),
#  ('maria,j', 8),
#  ('argent,gcg', 8),
#  ('ferreira,msg', 8),
#  ('kirkbride,mcg', 8),
#  ('ribeiro,r', 8),
#  ('smith,lb', 8),
#  ('renvoize,sa', 8),
#  ('cunha,cn', 8),
#  ('ianhez,m', 8),
#  ('cabral,e', 8),
#  ('pais,no', 8),
#  ('landrum,l', 8),
#  ('martins,ab', 8),
#  ('oliveira,pp', 8),
#  ('leao,ff', 8),
#  ('batista,jan', 8),
#  ('soares,c', 8),
#  ('pereira,la', 8),
#  ('bromley,gl', 8),
#  ('brom,acm', 8),
#  ('krieger,pl', 8),
#  ('ramos,kmo', 8),
#  ('pinheiro,ws', 8),
#  ('procopio,lc', 8),
#  ('barbosa,a', 8),
#  ('neto,la', 8),
#  ('silva,f', 8),
#  ('simpson,pl', 8),
#  ('gouvea,lk', 8),
#  ('farias,rrs', 8),
#  ('cristobal,cl', 8),
#  ('raulino,t', 8),
#  ('conceicao,as', 8),
#  ('souza,e', 8),
#  ('taylor,n', 8),
#  ('carneiro,d', 8),
#  ('brochado,al', 8),
#  ('bastos,ek', 8),
#  ('gomes,acm', 8),
#  ('jeronimo,ca', 8),
#  ('demo,c', 8),
#  ('batista,ac', 8),
#  ('campos,mtva', 8),
#  ('aquino,fg', 8),
#  ('fierro,af', 8),
#  ('guarimneto,g', 8),
#  ('sales,mf', 8),
#  ('sothers,ca', 8),
#  ('sanaiotti,t', 8),
#  ('henderson,a', 8),
#  ('silva,pit', 8),
#  ('araujo,rf', 8),
#  ('cruz,mp', 8),
#  ('andrade,laa', 8),
#  ('moura,io', 8),
#  ('egler,w', 8),
#  ('silva,df', 8),
#  ('guimaraes,rm', 8),
#  ('santos,ajv', 8),
#  ('moura,d', 8),
#  ('fontella,j', 8),
#  ('graziela', 8),
#  ('caceres,s', 8),
#  ('ferrucci,s', 8),
#  ('alho,k', 8),
#  ('maria', 8),
#  ('silva,l', 8),
#  ('rosario,c', 8),
#  ('astorino,a', 8),
#  ('cezare,chg', 8),
#  ('santos,rf', 8),
#  ('silva,ss', 8),
#  ('ferreira,la', 8),
#  ('isejima,em', 8),
#  ('cordeiro', 8),
#  ('silva,j', 8),
#  ('almeida,te', 8),
#  ('tressens,sg', 8),
#  ('valls,jfm', 8),
#  ('thorne,rf', 8),
#  ('ferrucci,ms', 8),
#  ('silva,mmr', 8),
#  ('lopes,mmm', 8),
#  ('meireles,ld', 8),
#  ('lima,lr', 8),
#  ('souza,d', 8),
#  ('belisario,m', 8),
#  ('assis,m', 8),
#  ('pozo,p', 8),
#  ('mota', 8),
#  ('santos,j', 8),
#  ('tavares,r', 8),
#  ('siqueirafilho,ja', 8),
#  ('ferraz,nms', 8),
#  ('lemos,rl', 8),
#  ('klein,vl', 8),
#  ('araujo,ac', 8),
#  ('duartesilva,ag', 8),
#  ('roveratti,j', 8),
#  ('pivari,mod', 8),
#  ('rabelo,bs', 8),
#  ('filho,rc', 8),
#  ('sousa,rc', 8),
#  ('borges,lm', 8),
#  ('farinaccio,ma', 8),
#  ('lopes,rn', 8),
#  ('feres,f', 8),
#  ('brotto,ml', 8),
#  ('mende', 8),
#  ('churchill,sp', 8),
#  ('souza,acm', 8),
#  ('marshall,c', 8),
#  ('chagas,ur', 8),
#  ('gibbs,pe', 7),
#  ('bertoldo,j', 7),
#  ('davis,ew', 7),
#  ('egler,wa', 7),
#  ('nogueira,e', 7),
#  ('mayo,sj', 7),
#  ('klein,r', 7),
#  ('esteves,gl', 7),
#  ('andrelinho', 7),
#  ('rizzo,ja', 7),
#  ('santos,gf', 7),
#  ('lima,am', 7),
#  ('abdala,gc', 7),
#  ('ferreira,hd', 7),
#  ('terwelle,bjh', 7),
#  ('gottsberger,g', 7),
#  ('medeiros,l', 7),
#  ('klein,rm', 7),
#  ('ramos,r', 7),
#  ('calago,k', 7),
#  ('vicentini,a', 7),
#  ('bulhao,cf', 7),
#  ('augusto,mm', 7),
#  ('ribeiro,mf', 7),
#  ('castro,i', 7),
#  ('unwin,m', 7),
#  ('beltrao,l', 7),
#  ('bahia,rp', 7),
#  ('jackson', 7),
#  ('abe,lm', 7),
#  ('euponino,a', 7),
#  ('vieira,g', 7),
#  ('ribamar,j', 7),
#  ('santos,ds', 7),
#  ('taroda,n', 7),
#  ('sano,sm', 7),
#  ('lima,iv', 7),
#  ('campos,lowf', 7),
#  ('sousa,gm', 7),
#  ('castro,ea', 7),
#  ('sena,l', 7),
#  ('zoccoli,dm', 7),
#  ('cress,a', 7),
#  ('mayworn,ma', 7),
#  ('salles,aeh', 7),
#  ('torres,rb', 7),
#  ('abreu,lcr', 7),
#  ('godoi,jv', 7),
#  ('costaf', 7),
#  ('santosh', 7),
#  ('bertolda,j', 7),
#  ('ramos,pcm', 7),
#  ('ramos,a', 7),
#  ('rickson,f', 7),
#  ('parker,d', 7),
#  ('aulino,o', 7),
#  ('rodrigues,k', 7),
#  ('pifano,ds', 7),
#  ('amaral,a', 7),
#  ('bastosdpreta,mag', 7),
#  ('cruvinel,h', 7),
#  ('farias,lg', 7),
#  ('webster,gl', 7),
#  ('dias,rra', 7),
#  ('magenta,m', 7),
#  ('miranda,e', 7),
#  ('cisneros,la', 7),
#  ('rodrig', 7),
#  ('rodri', 7),
#  ('minervino,js', 7),
#  ('fagg,jmf', 7),
#  ('barros,js', 7),
#  ('maroccolo,jf', 7),
#  ('chagas', 7),
#  ('meguro,m', 7),
#  ('souza,s', 7),
#  ('silva,ga', 7),
#  ('allem,ln', 7),
#  ('silva,eg', 7),
#  ('santos,ep', 7),
#  ('melo,mmrf', 7),
#  ('hahn,wj', 7),
#  ('souza,lrm', 7),
#  ('farah,ft', 7),
#  ('dambros,la', 7),
#  ('lisboa,p', 7),
#  ('valente,asm', 7),
#  ('nave,ag', 7),
#  ('silva,agp', 7),
#  ('ramos', 7),
#  ('milliken,w', 7),
#  ('fontana,a', 7),
#  ('valente,a', 7),
#  ('verboonen,sm', 7),
#  ('esteves,r', 7),
#  ('conrado', 7),
#  ('pinheiro,fc', 7),
#  ('filgueira,ts', 7),
#  ('pizziolo,w', 7),
#  ('daneu,l', 7),
#  ('nunes,r', 7),
#  ('rocha,d', 7),
#  ('nunes,rv', 7),
#  ('nicolack,v', 7),
#  ('fernandes,sdc', 7),
#  ('salino,a', 7),
#  ('leitaofilho,h', 7),
#  ('correa,c', 7),
#  ('almeida,s', 7),
#  ('santo,fse', 7),
#  ('coelho,mm', 7),
#  ('silva,accp', 7),
#  ('ferreira,jva', 7),
#  ('nu', 7),
#  ('silva,vd', 7),
#  ('rocha,w', 7),
#  ('emmert,p', 7),
#  ('castro,bm', 7),
#  ('machado,mc', 7),
#  ('souza,mc', 7),
#  ('noffs,lb', 7),
#  ('pitanga,gvf', 7),
#  ('rudall,p', 7),
#  ('simao', 7),
#  ('scaramuzza,cam', 7),
#  ('zuloaga,fo', 7),
#  ('okano,rmc', 7),
#  ('walte', 7),
#  ('garcia,ma', 7),
#  ('s', 7),
#  ('fonseca,js', 7),
#  ('lima,df', 7),
#  ('car', 7),
#  ('sartori,alb', 7),
#  ('cota,g', 7),
#  ('tiberi,m', 7),
#  ('sanches,id', 7),
#  ('farney,c', 7),
#  ('goncalves,aps', 7),
#  ('belchior,v', 7),
#  ('oliveira,alf', 7),
#  ('bodens,fwp', 7),
#  ('kellman,k', 7),
#  ('laeger,e', 7),
#  ('almeida,f', 7),
#  ('lima,te', 7),
#  ('amaral,ts', 7),
#  ('barbosa,hn', 7),
#  ('dantas,ts', 7),
#  ('sanaiot', 7),
#  ('si', 7),
#  ('faria,ad', 7),
#  ('aona,lys', 7),
#  ('mendoza,m', 7),
#  ('silva,lv', 7),
#  ('million,jl', 7),
#  ('cordeiro,aoo', 7),
#  ('o', 7),
#  ('ianhez,ml', 6),
#  ('rocha,mp', 6),
#  ('gifford,dr', 6),
#  ('pinheiro,rs', 6),
#  ('froes,rl', 6),
#  ('castellanos,a', 6),
#  ('hunt,dr', 6),
#  ('klein', 6),
#  ('wasshausen,dc', 6),
#  ('grearjunior,jw', 6),
#  ('daly,dc', 6),
#  ('sarmento,ac', 6),
#  ('fryxell,pa', 6),
#  ('souza,mg', 6),
#  ('borgatto,df', 6),
#  ('buzzi,f', 6),
#  ('castro,r', 6),
#  ('mitzi', 6),
#  ('fernandes,r', 6),
#  ('bida,a', 6),
#  ('landrum,s', 6),
#  ('custodio,j', 6),
#  ('santos,mr', 6),
#  ('freitas,cv', 6),
#  ('chagasesilva,fc', 6),
#  ('salviani,er', 6),
#  ('freitas,i', 6),
#  ('peixoto,m', 6),
#  ('morbeck,a', 6),
#  ('silva,jos', 6),
#  ('cozac,f', 6),
#  ('pedrosa,n', 6),
#  ('mota,rc', 6),
#  ('rabelo,bv', 6),
#  ('brako,l', 6),
#  ('reese,wd', 6),
#  ('dibben,m', 6),
#  ('leite,g', 6),
#  ('noleto,l', 6),
#  ('atkins,s', 6),
#  ('pabst,gfj', 6),
#  ('zoccoli,d', 6),
#  ('maury,c', 6),
#  ('santos,ad', 6),
#  ('silva,sm', 6),
#  ('sanches,cd', 6),
#  ('wongstchowski,m', 6),
#  ('farah,f', 6),
#  ('lohmann,lg', 6),
#  ('sa,spp', 6),
#  ('ruddall,p', 6),
#  ('pott,v', 6),
#  ('fonseca,l', 6),
#  ('jesus,gn', 6),
#  ('oliveira,s', 6),
#  ('mendonca,mja', 6),
#  ('rua,gh', 6),
#  ('pietrobom,mr', 6),
#  ('pires,f', 6),
#  ('kozovits,a', 6),
#  ('pinto,e', 6),
#  ('jose,m', 6),
#  ('kirkbride,jh', 6),
#  ('malta,ea', 6),
#  ('pereira,cb', 6),
#  ('cruz,t', 6),
#  ('torke,bm', 6),
#  ('barreto,kd', 6),
#  ('vicente,a', 6),
#  ('eladio', 6),
#  ('nunes,g', 6),
#  ('martins,mv', 6),
#  ('cozac,lfa', 6),
#  ('caio', 6),
#  ('william', 6),
#  ('costa,ef', 6),
#  ('rojas,a', 6),
#  ('alho,r', 6),
#  ('barbosa,ma', 6),
#  ('carvalho,sm', 6),
#  ('alves,as', 6),
#  ('morbeck', 6),
#  ('nascimento,e', 6),
#  ('pasquale,ga', 6),
#  ('netto,dam', 6),
#  ('barros,gv', 6),
#  ('neto,mp', 6),
#  ('senna,lr', 6),
#  ('lima,jc', 6),
#  ('souzasilva,s', 6),
#  ('lima,l', 6),
#  ('rapini,a', 6),
#  ('santos,lc', 6),
#  ('vilar,ts', 6),
#  ('breyer,lm', 6),
#  ('henriques,ok', 6),
#  ('r', 6),
#  ('polcheira,c', 6),
#  ('bonomo,vs', 6),
#  ('lola', 6),
#  ('otto', 6),
#  ('kuhlmann,mp', 6),
#  ('rolim,lb', 6),
#  ('wagner', 6),
#  ('laine,k', 6),
#  ('jansenjacobs,mj', 6),
#  ('souza,fs', 6),
#  ('vanini,a', 6),
#  ('lucas,e', 6),
#  ('martini,a', 6),
#  ('gentry,ah', 6),
#  ('ferreira,h', 6),
#  ('dutilh,j', 6),
#  ('rios,ls', 6),
#  ('chavez,de', 6),
#  ('lorenco,jlm', 6),
#  ('bonomo', 6),
#  ('piva,jh', 6),
#  ('foster,w', 6),
#  ('rocha,e', 6),
#  ...]

# %%
dfl.get_close_matches('harley,rm', names)
# Out:
# ['harley,rm', 'harley,r', 'marley,rm']

# %%
similarity('harley,rm','marley,rm')
# Out:
# 0.8888888888888888

# %%
G['marley,rm']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-7fbdb5c9ac5a> in <module>()
# ----> 1 G['marley,rm']
#
# /home/pedro/anaconda3/lib/python3.6/site-packages/networkx/classes/graph.py in __getitem__(self, n)
#     405         {1: {}}
#     406         """
# --> 407         return self.adj[n]
#     408
#     409     def add_node(self, n, attr_dict=None, **attr):
#
# KeyError: 'marley,rm'
